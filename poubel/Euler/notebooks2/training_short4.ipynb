# %% [markdown]
# # Entrainer les agents addi

# %% [markdown]
# ## Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/
# Out:
# /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler

# %%
#ou bien 
#!cp -r drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/* .

# %%
import Euler.core_solver as core
import Euler.agent_addi as aga
import Euler.neural_networks as nn

from Euler.backend import K
from Euler.param import Param,Projecter
from Euler.initial_conditions import GenParam,FuncGenerator

#from Euler.backend import K
import matplotlib.pyplot as plt
import popup_lib.popup as pop
import numpy as np
import copy
import time
# Out:
# Popup loaded!

# %%
order = 1
nx = 1200 // order
if order == 1:
  nx = 600
nx_ratio = nx // 100

param = Param(nx=nx,nx_ratio=nx_ratio,
              BC_solver=Param.BC_periodic,
              BC_model=Param.BC_periodic)

k_tf32=K("tf",32)

genParam=GenParam(param,kind=GenParam.kind_changing)
genParam.continuousPart_scale = 0.5
genParam.discontinuousPart_scale =0.5
genParam.sod_scale=0.5
genParam.same_discontinuity_locations=True
# genParam.initial_speed_factor= 1
genParam.initial_speed_factor= 0
genParam.changing_discountMinSpacing= 0.4
genParam.changing_discountMaxSpacing= 0.8
generator=FuncGenerator(genParam, param, k_tf32)
# Out:
# Param initialised with, nx=600, nx_coarse=99

# %%
fam_size=6
period_duration="15 seconds" #avant accélération: 60 secondes
all_agents=[]
nb_t = 800

# %%
## la première fois c'est plus long (traçage)
ti=time.time()
W_train=core.generate_fine_solutions(genParam,param, nb_t,k_tf32)
print("durée:",time.time()-ti)
W_train.shape
# Out:
# durée: 1.4795558452606201
# TensorShape([800, 64, 600, 3])

# %% [markdown]
# ## Définition des familles d'agent

# %%
model_struct = (32,64,32)
agent= aga.Agent_addi(param, nn.Difference_model_tricky(param,5,model_struct=model_struct),
                            watch_duration=20,
                            lossCoef_stab=1., #10.
                            lossCoef_ridge=3e-3,
                            lossCoef_disHLL=1e-2, #1.
                            nb_optimization=15,
                            score_computed_last_time=True
                            )

# %%
def family_full(window_size,color):
        name="full_"+str(window_size)
        agents=[]
        model_struct = (32,64,32)
        for _ in range(fam_size):
            agent= aga.Agent_addi(param, nn.Difference_model_tricky(param,window_size,model_struct=model_struct),
                            watch_duration=20,
                            lossCoef_stab=20., #10.
                            lossCoef_ridge=3e-3,
                            lossCoef_disHLL=1.,
                            nb_optimization=15,
                            score_computed_last_time=True
                            )
            agents.append(agent)
            all_agents.append(agent)
            
        return pop.Family_trainer(
            agents=agents,
            nb_bestweights_averaged=3,
            nb_strong=3,
            period_duration=period_duration,
            name=name,
            color=color)

family_trainers=[
                 family_full(5,"red"),
                #  family_full(3,"blue"),
                 ]

def load_data():
    nb_t=800
    ti=time.time()
    W_train = core.generate_fine_solutions(genParam,param, nb_t,k_tf32)
    W_val = core.generate_fine_solutions(genParam,param, nb_t,k_tf32)
    print(f"|génération des données, durée: {time.time()-ti:.2f} ",end="")
    
    ti=time.time()
    for agent in all_agents:
        agent.load_WY_train(W_train)
        agent.load_WY_valid(W_val)
    print(f"|load données,durée: {time.time()-ti:.2f}",end="")

# %%
try:
    for i in range(50):
        load_data()
        for family_trainer in family_trainers:
            family_trainer.period()
except KeyboardInterrupt:
    for family_trainer in family_trainers:
        #pour pouvoir reprendre si on veut
        family_trainer.interupt_period()
# Out:
# |génération des données, durée: 0.91 traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:5 out of the last 9 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b6257170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b6208b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b6180c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b6193cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b60f5cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b61ab0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b610d830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b602db00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b6042950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb445944c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb445944950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4b6208ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb4458cbef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fb44589a7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# |load données,durée: 9.27
# full_5,échauffement Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': True
# a↗0.991Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': True
# b↗1.1693Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:5 out of the last 5 calls to <function Agent_addi._predict_accelerated at 0x7fb28d5ba8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:6 out of the last 6 calls to <function Agent_addi._predict_accelerated at 0x7fb28d5ba8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# c↗1.0189Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:7 out of the last 7 calls to <function Agent_addi._predict_accelerated at 0x7fb28c9baa70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:8 out of the last 8 calls to <function Agent_addi._predict_accelerated at 0x7fb28c9baa70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# d↗0.9969Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:9 out of the last 9 calls to <function Agent_addi._predict_accelerated at 0x7fb28bdb1f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:10 out of the last 10 calls to <function Agent_addi._predict_accelerated at 0x7fb28bdb1f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# e↗0.9245Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7fb28b1b0050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _test_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7fb28b1b0050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# f↗0.9818|génération des données, durée: 0.92 |load données,durée: 7.44
# full_5,period:1 a↗1.0559b↗1.3023c↗1.0715--, mutations:e⇇b||génération des données, durée: 0.92 |load données,durée: 7.33
# full_5,period:2 f↗1.1184a↗1.1313b↗1.3858c↗1.1285, mutations:d⇇b||génération des données, durée: 0.92 |load données,durée: 7.48
# full_5,period:3 d↗1.2964e↗1.3419f↗1.1955-, mutations:a⇇d||génération des données, durée: 0.92 |load données,durée: 7.34
# full_5,period:4 b↗1.4006c↗1.2088-, mutations:f⇇d||génération des données, durée: 0.92 |load données,durée: 7.38
# full_5,period:5 e↗1.3937f↗1.3358a↗1.358b↗1.4278, mutations:c⇇a||génération des données, durée: 0.90 |load données,durée: 7.41
# full_5,period:6 c↗1.5471d↗1.3813e↗1.8161f↗1.5134, mutations:a⇇d⇇c||génération des données, durée: 0.91 |load données,durée: 7.35
# full_5,period:7 a↗1.4122---, mutations:d⇇b⇇c||génération des données, durée: 0.89 |load données,durée: 7.31
# full_5,period:8 e↗1.9408---, mutations:b⇇f||génération des données, durée: 0.90 |load données,durée: 7.29
# full_5,period:9 ----, mutations:d⇇b⇇c⇇f||génération des données, durée: 0.91 |load données,durée: 7.35
# full_5,period:10 ---, mutations:c⇇a↫c||génération des données, durée: 0.93 |load données,durée: 7.32
# full_5,period:11 d↗1.4198e↗2.3188--, mutations:a⇇d⇇c⇇c||génération des données, durée: 0.90 |load données,durée: 7.32
# full_5,period:12 b↗1.466---, mutations:c⇇a↫c↫c||génération des données, durée: 0.91 |load données,durée: 7.37
# full_5,period:13 -a↗1.4391b↗1.5678-, mutations:c⇇a↫c↫c↫c||génération des données, durée: 0.91 |load données,durée: 7.25
# full_5,period:14 d↗1.4284-

# %% [markdown]
# ### Historique des `famparams`

# %%
def plot_history_famparams():
    # keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","lossCoef_Laplacian","watch_duration","score"]
    keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","watch_duration","score"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_famparams()

# %% [markdown]
# ### Historique des trois `loss`

# %%
def plot_history_losses():
    # keys=["loss_stab","loss_disHLL","loss_ridge","loss_Laplacian"]
    keys=["loss_stab","loss_disHLL","loss_ridge"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_losses()

# %% [markdown]
# ### Observation des famparams

# %%
import tensorflow as tf
family_trainer=family_trainers[0]

for char in ['a', 'b', 'c', 'd', 'e', 'f']:
    best_agent=family_trainer.agents[char].agent
    print(char)
    print(best_agent.famparams)
    print(best_agent.agent_score())

best_agent=family_trainer.get_best_agent()
# best_agent=family_trainer.agents['a'].agent
print("best agent")
print(best_agent.famparams)
# print(best_agent.agent_score())

# %% [markdown]
# ## Testons sur le jeu "loop" (périodique)

# %% [markdown]
# ## Testons le long du temps

# %%
def compare_along_the_time(kind):
    nb_t = 2000
    
    if kind==GenParam.kind_sod:
        param.BC_model=param.BC_solver=Param.BC_neumann
    genParam.kind=kind
    generator=FuncGenerator(genParam,param,k_tf32)
    W_val = core.generate_fine_solutions(genParam, param, nb_t, k_tf32)
    
    best_agent.load_WY_valid(W_val)

    res_fine_proj,res_HLL,res_model=best_agent.predict()
        
    nb_batch_plot=5
    if nb_batch_plot>W_val.shape[1]:
        nb_batch_plot=W_val.shape[1]
    nb_t_plot=4
    step=nb_t//nb_t_plot
    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    if nb_batch_plot==1:ax=ax[:,tf.newaxis]
    for i in range(nb_t_plot):
        for j in range(nb_batch_plot):
            t=i*step
            ax[i,j].plot(res_fine_proj[t,j,:,0],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,0],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,0],color="r",label="model")
    ax[0,0].legend()    

    fig.tight_layout()
    
    errors_HLL=tf.reduce_mean((res_fine_proj-res_HLL)**2,axis=[1,2,3])
    errors_model=tf.reduce_mean((res_fine_proj-res_model)**2,axis=[1,2,3])
    
    fig,ax=plt.subplots()
    ax.plot(errors_HLL,label="HLL")
    ax.plot(errors_model,label="model")

    if (np.max(errors_model)>0.1):
        ax.set_ylim(0,0.1)
    
    ax.legend()
    ax.set_xlabel("time")

    plt.show()

# %% [markdown]
# ### kind Loop

# %%
compare_along_the_time(GenParam.kind_loop)

# %% [markdown]
# ### kind changing

# %%
compare_along_the_time(GenParam.kind_changing)

# %% [markdown]
# ### kind Sod

# %%
compare_along_the_time(GenParam.kind_sod)

# %% [markdown]
# ### Kind random Sod

# %%
compare_along_the_time(GenParam.kind_random_sod)
