# %% [markdown]
# # Entrainer les agents addi

# %% [markdown]
# ## Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %reset -f

# %%
# %cd /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/
# Out:
# /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler

# %%
#ou bien 
#!cp -r drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/* .

# %%
import Euler.core_solver as core
import Euler.agent_addi as aga
import Euler.neural_networks as nn

from Euler.backend import K
from Euler.param import Param,Projecter
from Euler.initial_conditions import *

#from Euler.backend import K
import matplotlib.pyplot as plt
import popup_lib.popup as pop
import numpy as np
import copy
import time

import tensorflow as tf
# Out:
# Popup loaded!

# %% [markdown]
# Attention: `BC_periodic` rajoute une discontinuité au bord pour chaque fonction non périodique.

# %%
param = Param(nx=1000,nx_ratio=10,
              BC_solver=Param.BC_periodic,
              BC_model=Param.BC_periodic)
nb_t=800
k_tf32=K("tf",32)
# Out:
# Param initialised with, nx=1000, nx_coarse=99

# %% [markdown]
# ## Génération des données

# %%
def show_w_init(W):
    fig,axs=plt.subplots(3,3,sharex="all",sharey="all",figsize=(6,6))
    axs=axs.flatten()

    for i in range(9):
        axs[i].plot(W[i,:,0],label=r"$\rho$")
        axs[i].plot(W[i,:,1],label=r"$\rho V$")
        axs[i].plot(W[i,:,2],label="$E$")
    plt.legend()
    plt.show()

# %%
res=init_non_periodic(param,9)
print(res.shape)
show_w_init(res)
# Out:
# (9, 1000, 3)

# %%
res=init_periodic(param,9)
print(res.shape)
show_w_init(res)
# Out:
# (9, 1000, 3)

# %%
#attention, si les random sod vont trop proche de zéro => ça pète
res= init_random_sod(param, batch_size=10, minimum_E=0.05, maximal_jump_E=2, minimum_rho=0.05, maximal_jump_rho=2)
print(res.shape)
show_w_init(res)
# Out:
# (10, 1000, 3)

# %% [markdown]
# * Il faut mettre des jeux d'entrainement assez gros pour limiter le hasard du sampling
# * Quand, au bout d'une longue stagnation, tous les agents s'améliore d'un coup, c'est suspect !
# * On ne peut pas mettre non plus des batchs trop gros à cause de la limite des GPU;  cela bloque très vite ex de jeu qui passe pas:
#
#         nb_t=1000, batch_size = 140, nx=1000.

# %%
def data_for_train():
    return init_periodic(param,120)

# %% [markdown]
# Il est tout à fait possible de mettre dans val des K-tests déterministes

# %%
def data_for_val():
    return init_periodic(param,120)

# %% [markdown]
# ### Test du solveur

# %%
def generate_fine_solutions(for_train):
    if for_train:
        w_init=data_for_train()
    else:
        w_init=data_for_val()

    
    return core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val=generate_fine_solutions(True)
W_val.shape
# Out:
# traçage de la fonction 'compute_solutions_order1' avec les arguments primitif:
# 		 nb_t,dt_over_dx,dt_over_dx_coarse,nx,nx_coarse,BC_solver,gamma,is_coarse=
# 		 800 0.1 0.009899999999999999 1000 99 periodic 1.4 False
# 		 et le tenseurs W_init de shape: (120, 1000, 3)
# TensorShape([800, 120, 1000, 3])

# %% [markdown]
# ## Entrainement

# %% [markdown]
# ### Définition des familles d'agent

# %%
fam_size=6
#un durée pour que les agents puissent tous faire leur 'nb_optimization' optimizations
#attention, cela dépend beaucoup de la watch_duration
period_duration="6 steps"#"15 seconds" 
all_agents=[]

# %%
def family_full(window_size,color):
        name="full_"+str(window_size)
        agents=[]
        model_struct = (32,64,32)
        for _ in range(fam_size):
            model=nn.Difference_model_several_convo(param,4)#4= taille du kernel 
                 
            agent= aga.Agent_addi(param, 
                            model,
                            watch_duration=20, #20
                            lossCoef_stab=100, #10.
                            lossCoef_ridge=1e-3,
                            lossCoef_disHLL=1,
                            nb_optimization=15,
                            )
            agents.append(agent)
            all_agents.append(agent)
            
        return pop.Family_trainer(
            agents=agents,
            nb_bestweights_averaged=3,
            nb_strong=3,
            nb_weak=2,
            period_duration=period_duration,
            name=name,
            color=color)

family_trainers=[
                 family_full(5,"red"),
                 #family_full(7,"blue"),
                 ]

# %%
def load_data():
    ti=time.time()
    W_train = generate_fine_solutions(True)
    W_val = generate_fine_solutions(False)
    print(f"|génération des données, durée: {time.time()-ti:.2f} ",end="")
    
    ti=time.time()
    for agent in all_agents:
        agent.load_WY_train(W_train)
        agent.load_WY_valid(W_val)
    print(f"|load données,durée: {time.time()-ti:.2f}",end="")

# %% [markdown]
# ### LA BOUCLE

# %%
try:
    for i in range(50):
        load_data()
        for family_trainer in family_trainers:
            family_trainer.period()
except KeyboardInterrupt:
    for family_trainer in family_trainers:
        #pour pouvoir reprendre si on veut
        family_trainer.interupt_period()
# Out:
# |génération des données, durée: 1.11 traçage de la méthode _load_WY_accelerated2 pour les paramètres: W:(800, 120, 1000, 3), nx_ratio:10
# |load données,durée: 0.51
# full_5,échauffement Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# a↗1.0347Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# b↗1.0528Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:5 out of the last 5 calls to <function Agent_addi._predict_accelerated at 0x7f272a3f3170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:6 out of the last 6 calls to <function Agent_addi._predict_accelerated at 0x7f272a3f3170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# c↗1.0318Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:7 out of the last 7 calls to <function Agent_addi._predict_accelerated at 0x7f272b6dc4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:8 out of the last 8 calls to <function Agent_addi._predict_accelerated at 0x7f272b6dc4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# d↗1.0824Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:9 out of the last 9 calls to <function Agent_addi._predict_accelerated at 0x7f26a7cb3e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:10 out of the last 10 calls to <function Agent_addi._predict_accelerated at 0x7f26a7cb3e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# e↗1.0792Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 periodic 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7f26a6ff30e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7f26a6ff30e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# f↗1.0998|génération des données, durée: 1.35 |load données,durée: 0.01
# full_5,period:1 -b↗1.2918c↗1.2751d↗1.2619e↗1.2212f↗1.2794
# /!\ L'agent:a est décadent pour la 0-ième fois consécutive; record:1.0347399711608887, scores courants:deque([1.0347399711608887, 1.0233807563781738], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇f|e⇇f|a⇇f↫a||génération des données, durée: 1.06 |load données,durée: 0.01
# full_5,period:2 a↗1.3518b↗1.3589c↗1.5147d↗1.4568e↗1.3598f↗1.4946
# /!\ L'agent:a est décadent pour la 1-ième fois consécutive; record:1.3518107732137044, scores courants:deque([1.0347399711608887, 1.3518107732137044], maxlen=3), best_famparams: {'lossCoef_stab': 70.0, 'lossCoef_ridge': 0.0007, 'lossCoef_disHLL': 1.5, 'watch_duration': 22}
# , mutations:a⇇f↫a⇇f|b⇇f|a⇇f↫a⇇f↫a||génération des données, durée: 1.28 |load données,durée: 0.01
# full_5,period:3 a↗1.6398b↗1.6097c↗1.6117d↗2.1442e↗1.569f↗1.8589
# /!\ L'agent:e est décadent pour la 0-ième fois consécutive; record:1.5689579645792644, scores courants:deque([1.2793647448221843, 1.3597936630249023, 1.5689579645792644], maxlen=3), best_famparams: {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0007, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
# , mutations:e⇇f⇇f|c⇇d|e⇇f⇇f↫e||génération des données, durée: 1.09 |load données,durée: 0.01
# full_5,period:4 a↗2.1535b↗2.0134c↗1.6807-e↗1.9932f↗2.2964
# /!\ L'agent:a est décadent pour la 2-ième fois consécutive; record:2.1535016695658364, scores courants:deque([1.3518107732137044, 1.6397711435953777, 2.1535016695658364], maxlen=3), best_famparams: {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0015, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
# , mutations:b⇇f⇇d|a⇇f↫a⇇f↫a⇇b|a⇇f↫a⇇f↫a⇇b⇇f||génération des données, durée: 1.10 |load données,durée: 0.01
# full_5,period:5 ---d↗2.3082e↗2.2392f↗2.422
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:1.680712381998698, scores courants:deque([2.1442271868387857, 1.680712381998698, 1.6537497838338215], maxlen=3), best_famparams: {'lossCoef_stab': 70.0, 'lossCoef_ridge': 0.0007, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
# , mutations:c⇇d⇇d|b⇇f⇇d⇇f|c⇇d⇇d↫c||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:6 -b↗2.7466c↗2.8027d↗2.4259e↗2.5253-
# /!\ L'agent:a est décadent pour la 0-ième fois consécutive; record:2.1535016695658364, scores courants:deque([2.296356678009033, 1.7931338946024578, 1.8082078297932942], maxlen=3), best_famparams: {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0015, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
#
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:2.8026911417643228, scores courants:deque([1.680712381998698, 2.8026911417643228], maxlen=3), best_famparams: {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0015, 'lossCoef_disHLL': 0.7, 'watch_duration': 18}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b|c⇇d⇇d↫c⇇b|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a|c⇇d⇇d↫c⇇b↫c||génération des données, durée: 1.11 |load données,durée: 0.01
# full_5,period:7 a↗2.469-c↗3.2108-e↗2.5341-
# /!\ L'agent:f est décadent pour la 0-ième fois consécutive; record:2.4219757715861, scores courants:deque([2.4219757715861, 2.3521251678466797, 2.1877334912618003], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e|f⇇e|f⇇e↫f||génération des données, durée: 1.31 |load données,durée: 0.01
# full_5,period:8 a↗2.5082--d↗2.5172-f↗2.7146, mutations:d⇇f|e⇇f⇇f↫e⇇f||génération des données, durée: 1.05 |load données,durée: 0.01
# full_5,period:9 a↗2.571b↗3.1891-d↗2.5775e↗3.2154-
# /!\ L'agent:a est décadent pour la 1-ième fois consécutive; record:2.5709816614786782, scores courants:deque([2.534135182698568, 2.508209228515625, 2.5709816614786782], maxlen=3), best_famparams: {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.00105, 'lossCoef_disHLL': 1.0499999999999998, 'watch_duration': 24}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e|f⇇e↫f⇇e|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a||génération des données, durée: 1.23 |load données,durée: 0.01
# full_5,period:10 a↗2.9837-----
# /!\ L'agent:d est décadent pour la 0-ième fois consécutive; record:2.5775362650553384, scores courants:deque([2.7145732243855796, 2.5775362650553384, 2.2036892573038735], maxlen=3), best_famparams: {'lossCoef_stab': 157.5, 'lossCoef_ridge': 0.0033750000000000004, 'lossCoef_disHLL': 1.5749999999999997, 'watch_duration': 22}
#
# /!\ L'agent:c est décadent pour la 2-ième fois consécutive; record:3.2107909520467124, scores courants:deque([2.6360956827799478, 2.9882148106892905, 2.3549623489379883], maxlen=3), best_famparams: {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.00049, 'lossCoef_disHLL': 0.48999999999999994, 'watch_duration': 20}
# , mutations:d⇇f⇇b|c⇇d⇇d↫c⇇b↫c⇇a|d⇇f⇇b↫d|c⇇d⇇d↫c⇇b↫c⇇a⇇b||génération des données, durée: 1.21 |load données,durée: 0.01
# full_5,period:11 ---d↗2.6181-f↗3.1713
# /!\ L'agent:d est décadent pour la 1-ième fois consécutive; record:2.618140538533529, scores courants:deque([2.5775362650553384, 2.618140538533529], maxlen=3), best_famparams: {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.00105, 'lossCoef_disHLL': 1.0499999999999998, 'watch_duration': 20}
# , mutations:d⇇f⇇b↫d⇇b|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b|d⇇f⇇b↫d⇇b↫d||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:12 ---d↗2.6225e↗3.2388f↗3.7022
# /!\ L'agent:d est décadent pour la 2-ième fois consécutive; record:2.6224560737609863, scores courants:deque([2.618140538533529, 2.6224560737609863], maxlen=3), best_famparams: {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.00049, 'lossCoef_disHLL': 0.48999999999999994, 'watch_duration': 20}
# , mutations:d⇇f⇇b↫d⇇b↫d⇇f|b⇇f⇇d⇇f⇇f|d⇇f⇇b↫d⇇b↫d⇇f⇇f||génération des données, durée: 1.10 |load données,durée: 0.01
# full_5,period:13 ------, mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f||génération des données, durée: 1.26 |load données,durée: 0.01
# full_5,period:14 ---d↗3.0684--
# /!\ L'agent:e est décadent pour la 1-ième fois consécutive; record:3.238790512084961, scores courants:deque([3.238790512084961, 2.7855437596639, 2.796123186747233], maxlen=3), best_famparams: {'lossCoef_stab': 157.5, 'lossCoef_ridge': 0.001575, 'lossCoef_disHLL': 0.7349999999999999, 'watch_duration': 26}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c|e⇇f⇇f↫e⇇f⇇c|e⇇f⇇f↫e⇇f⇇c↫e||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:15 a↗3.488b↗3.7837--e↗3.3307f↗3.7237
# /!\ L'agent:d est décadent pour la 0-ième fois consécutive; record:3.068354606628418, scores courants:deque([2.2867139180501304, 3.068354606628418, 2.6575522422790527], maxlen=3), best_famparams: {'lossCoef_stab': 165.375, 'lossCoef_ridge': 0.0016537499999999998, 'lossCoef_disHLL': 0.7717499999999997, 'watch_duration': 26}
# , mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d||génération des données, durée: 1.34 |load données,durée: 0.01
# full_5,period:16 ---d↗3.6049--
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:3.2107909520467124, scores courants:deque([3.7837416330973306, 2.434027989705404], maxlen=3), best_famparams: {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.00049, 'lossCoef_disHLL': 0.48999999999999994, 'watch_duration': 20}
# , mutations:e⇇f⇇f↫e⇇f⇇c↫e⇇b|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:17 --c↗3.7129-e↗3.7503f↗4.1468
# /!\ L'agent:a est décadent pour la 2-ième fois consécutive; record:3.4879528681437173, scores courants:deque([3.4879528681437173, 3.168598175048828, 3.2989679972330728], maxlen=3), best_famparams: {'lossCoef_stab': 165.375, 'lossCoef_ridge': 0.00354375, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f||génération des données, durée: 1.24 |load données,durée: 0.01
# full_5,period:18 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:3.7837416330973306, scores courants:deque([3.4779351552327475, 3.356792449951172, 3.282597859700521], maxlen=3), best_famparams: {'lossCoef_stab': 165.375, 'lossCoef_ridge': 0.00354375, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:b⇇f⇇d⇇f⇇f⇇c|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e|b⇇f⇇d⇇f⇇f⇇c↫b||génération des données, durée: 1.22 |load données,durée: 0.01
# full_5,period:19 ------
# /!\ L'agent:a est décadent pour la 0-ième fois consécutive; record:3.4879528681437173, scores courants:deque([4.1467851003011065, 2.922886848449707, 2.7745755513509116], maxlen=3), best_famparams: {'lossCoef_stab': 165.375, 'lossCoef_ridge': 0.00354375, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
#
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:3.7837416330973306, scores courants:deque([3.7837416330973306, 3.0487359364827475], maxlen=3), best_famparams: {'lossCoef_stab': 165.375, 'lossCoef_ridge': 0.00354375, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e|b⇇f⇇d⇇f⇇f⇇c↫b⇇f|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a|b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b||génération des données, durée: 1.05 |load données,durée: 0.01
# full_5,period:20 a↗3.5963--d↗3.631--, mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b||génération des données, durée: 1.18 |load données,durée: 0.01
# full_5,period:21 ------
# /!\ L'agent:a est décadent pour la 1-ième fois consécutive; record:3.596341133117676, scores courants:deque([3.4879528681437173, 3.596341133117676, 3.1332340240478516], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.37815749999999987, 'watch_duration': 26}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a||génération des données, durée: 1.07 |load données,durée: 0.01
# full_5,period:22 a↗4.1425b↗4.0353c↗3.7394---
# /!\ L'agent:d est décadent pour la 1-ième fois consécutive; record:3.6310291290283203, scores courants:deque([3.7837416330973306, 3.2892058690389, 3.3333428700764975], maxlen=3), best_famparams: {'lossCoef_stab': 354.375, 'lossCoef_ridge': 0.00354375, 'lossCoef_disHLL': 0.7717499999999997, 'watch_duration': 26}
# , mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d||génération des données, durée: 1.17 |load données,durée: 0.01
# full_5,period:23 ---d↗3.7467--
# /!\ L'agent:f est décadent pour la 1-ième fois consécutive; record:4.1467851003011065, scores courants:deque([3.4083162943522134, 3.6389748255411782, 3.6061232884724936], maxlen=3), best_famparams: {'lossCoef_stab': 236.25, 'lossCoef_ridge': 0.0023625, 'lossCoef_disHLL': 0.5144999999999998, 'watch_duration': 28}
# , mutations:b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a|f⇇e↫f⇇e⇇e|f⇇e↫f⇇e⇇e↫f||génération des données, durée: 1.12 |load données,durée: 0.01
# full_5,period:24 ---d↗4.059--
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:3.7393598556518555, scores courants:deque([3.7393598556518555, 2.925011952718099, 3.1339597702026367], maxlen=3), best_famparams: {'lossCoef_stab': 354.375, 'lossCoef_ridge': 0.0016537499999999998, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c||génération des données, durée: 1.06 |load données,durée: 0.01
# full_5,period:25 ------
# /!\ L'agent:c est décadent pour la 2-ième fois consécutive; record:3.7393598556518555, scores courants:deque([3.7393598556518555, 3.070826530456543], maxlen=3), best_famparams: {'lossCoef_stab': 354.375, 'lossCoef_ridge': 0.0016537499999999998, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:26 ---d↗4.0892e↗3.9757-
# /!\ L'agent:a est décadent pour la 2-ième fois consécutive; record:4.142465591430664, scores courants:deque([3.931729316711426, 3.3555221557617188, 4.105007171630859], maxlen=3), best_famparams: {'lossCoef_stab': 165.375, 'lossCoef_ridge': 0.00354375, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 30}
# , mutations:b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a⇇f|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d⇇d||génération des données, durée: 1.22 |load données,durée: 0.01
# full_5,period:27 ------
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:3.7393598556518555, scores courants:deque([4.142465591430664, 3.578296979268392, 3.3612187703450522], maxlen=3), best_famparams: {'lossCoef_stab': 354.375, 'lossCoef_ridge': 0.0016537499999999998, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a⇇f⇇a|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:28 ------
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:3.7393598556518555, scores courants:deque([3.7393598556518555, 3.707603136698405], maxlen=3), best_famparams: {'lossCoef_stab': 354.375, 'lossCoef_ridge': 0.0016537499999999998, 'lossCoef_disHLL': 0.36014999999999986, 'watch_duration': 26}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d|b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a⇇f⇇a⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c||génération des données, durée: 1.15 |load données,durée: 0.01
# full_5,period:29 --c↗3.7937---
# /!\ L'agent:c est décadent pour la 2-ième fois consécutive; record:3.793706258138021, scores courants:deque([3.7393598556518555, 3.793706258138021], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 26}
# , mutations:e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f||génération des données, durée: 1.17 |load données,durée: 0.01
# full_5,period:30 ------
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:3.793706258138021, scores courants:deque([4.1467851003011065, 2.932854334513346], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 26}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d|b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a⇇f⇇a⇇d⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c||génération des données, durée: 1.13 |load données,durée: 0.01
# full_5,period:31 ------
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:3.793706258138021, scores courants:deque([3.793706258138021, 3.2911510467529297], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 26}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c||génération des données, durée: 1.07 |load données,durée: 0.01
# full_5,period:32 -b↗4.1737--e↗4.1923-
# /!\ L'agent:c est décadent pour la 2-ième fois consécutive; record:3.793706258138021, scores courants:deque([3.793706258138021, 3.5676164627075195], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 26}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d⇇d⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e||génération des données, durée: 1.07 |load données,durée: 0.01
# full_5,period:33 -b↗4.2008----, mutations:f⇇e↫f⇇e⇇e↫f⇇b|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e||génération des données, durée: 1.22 |load données,durée: 0.01
# full_5,period:34 ------
# /!\ L'agent:e est décadent pour la 2-ième fois consécutive; record:4.192324320475261, scores courants:deque([4.192324320475261, 3.816868782043457, 3.52908992767334], maxlen=3), best_famparams: {'lossCoef_stab': 115.76249999999999, 'lossCoef_ridge': 0.005315625, 'lossCoef_disHLL': 0.2521049999999999, 'watch_duration': 32}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d⇇d⇇f⇇f|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b||génération des données, durée: 1.06 |load données,durée: 0.01
# full_5,period:35 ------
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:3.793706258138021, scores courants:deque([3.7532100677490234, 3.609954833984375, 3.484338124593099], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 26}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d⇇d⇇f⇇f⇇f|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c||génération des données, durée: 1.11 |load données,durée: 0.01
# full_5,period:36 --c↗4.0375---
# /!\ L'agent:e est décadent pour la 0-ième fois consécutive; record:4.192324320475261, scores courants:deque([4.200753211975098, 3.441901206970215, 3.7247947057088218], maxlen=3), best_famparams: {'lossCoef_stab': 115.76249999999999, 'lossCoef_ridge': 0.005315625, 'lossCoef_disHLL': 0.2521049999999999, 'watch_duration': 32}
# , mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e||génération des données, durée: 1.20 |load données,durée: 0.01
# full_5,period:37 ------, mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f⇇e|a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d⇇d⇇f⇇f⇇f⇇e||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:38 -b↗4.4097c↗4.0801--f↗4.2083, mutations:e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f⇇e⇇f||génération des données, durée: 1.08 |load données,durée: 0.01
# full_5,period:39 ------
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:4.08010991414388, scores courants:deque([3.744434038798014, 4.08010991414388, 3.626342455546061], maxlen=3), best_famparams: {'lossCoef_stab': 56.723624999999984, 'lossCoef_ridge': 0.0026046562499999993, 'lossCoef_disHLL': 0.26471024999999987, 'watch_duration': 28}
# , mutations:a⇇f↫a⇇f↫a⇇b⇇f⇇b↫a⇇e⇇e↫a⇇b⇇f⇇f⇇f⇇e↫a⇇f↫a⇇d⇇d⇇f⇇f⇇f⇇e⇇b|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c||génération des données, durée: 1.09 |load données,durée: 0.01
# full_5,period:40 a↗4.179--d↗4.221--
# /!\ L'agent:c est décadent pour la 2-ième fois consécutive; record:4.08010991414388, scores courants:deque([4.08010991414388, 3.958164850870768], maxlen=3), best_famparams: {'lossCoef_stab': 56.723624999999984, 'lossCoef_ridge': 0.0026046562499999993, 'lossCoef_disHLL': 0.26471024999999987, 'watch_duration': 28}
#
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:4.4096676508585615, scores courants:deque([4.4096676508585615, 3.842731793721517, 3.6634543736775718], maxlen=3), best_famparams: {'lossCoef_stab': 81.03374999999998, 'lossCoef_ridge': 0.0037209374999999994, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 26}
# , mutations:b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a⇇f⇇a⇇d⇇d⇇e|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d|b⇇f⇇d⇇f⇇f⇇c↫b⇇f↫b⇇a⇇a⇇f⇇a⇇d⇇d⇇e⇇f||génération des données, durée: 1.16 |load données,durée: 0.01
# full_5,period:41 ------
# /!\ L'agent:d est décadent pour la 2-ième fois consécutive; record:4.220978418986003, scores courants:deque([3.654296875, 4.220978418986003, 3.5921198527018228], maxlen=3), best_famparams: {'lossCoef_stab': 182.32593749999995, 'lossCoef_ridge': 0.0018232593749999994, 'lossCoef_disHLL': 0.39706537499999983, 'watch_duration': 30}
# , mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f⇇e⇇f⇇f|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e|d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f⇇e⇇f⇇f⇇e||génération des données, durée: 1.29 |load données,durée: 0.01
# full_5,period:42 --c↗4.0985-e↗4.3767-
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:4.098498980204265, scores courants:deque([4.220978418986003, 3.702905019124349, 4.098498980204265], maxlen=3), best_famparams: {'lossCoef_stab': 127.62815624999996, 'lossCoef_ridge': 0.002734889062499999, 'lossCoef_disHLL': 0.27794576249999986, 'watch_duration': 28}
# , mutations:f⇇e↫f⇇e⇇e↫f⇇b⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c||génération des données, durée: 1.15 |load données,durée: 0.01
# full_5,period:43 ------
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:4.098498980204265, scores courants:deque([4.098498980204265, 3.4179884592692056], maxlen=3), best_famparams: {'lossCoef_stab': 127.62815624999996, 'lossCoef_ridge': 0.002734889062499999, 'lossCoef_disHLL': 0.27794576249999986, 'watch_duration': 28}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d|f⇇e↫f⇇e⇇e↫f⇇b⇇d⇇b|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c||génération des données, durée: 1.05 |load données,durée: 0.01
# full_5,period:44 ------
# /!\ L'agent:c est décadent pour la 2-ième fois consécutive; record:4.098498980204265, scores courants:deque([4.098498980204265, 3.452655474344889], maxlen=3), best_famparams: {'lossCoef_stab': 127.62815624999996, 'lossCoef_ridge': 0.002734889062499999, 'lossCoef_disHLL': 0.27794576249999986, 'watch_duration': 28}
#
# /!\ L'agent:e est décadent pour la 1-ième fois consécutive; record:4.376744906107585, scores courants:deque([4.376744906107585, 3.4162267049153647, 2.977047602335612], maxlen=3), best_famparams: {'lossCoef_stab': 173.64374999999998, 'lossCoef_ridge': 0.0037209375, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 30}
# , mutations:e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c⇇b|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c⇇b⇇d|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e⇇d↫e||génération des données, durée: 1.06 |load données,durée: 0.01
# full_5,period:45 a↗4.1908-----, mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f⇇e⇇f⇇f⇇e⇇e|f⇇e↫f⇇e⇇e↫f⇇b⇇d⇇b⇇e||génération des données, durée: 1.09 |load données,durée: 0.01
# full_5,period:46 ------
# /!\ L'agent:e est décadent pour la 2-ième fois consécutive; record:4.376744906107585, scores courants:deque([4.376744906107585, 3.462490717569987, 3.5181757609049478], maxlen=3), best_famparams: {'lossCoef_stab': 173.64374999999998, 'lossCoef_ridge': 0.0037209375, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 30}
# , mutations:f⇇e↫f⇇e⇇e↫f⇇b⇇d⇇b⇇e⇇f|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e⇇d↫e⇇b|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e⇇d↫e⇇b⇇d||génération des données, durée: 1.07 |load données,durée: 0.01
# full_5,period:47 ------
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:4.098498980204265, scores courants:deque([3.985531489054362, 3.483304023742676, 3.336796760559082], maxlen=3), best_famparams: {'lossCoef_stab': 127.62815624999996, 'lossCoef_ridge': 0.002734889062499999, 'lossCoef_disHLL': 0.27794576249999986, 'watch_duration': 28}
# , mutations:f⇇e↫f⇇e⇇e↫f⇇b⇇d⇇b⇇e⇇f⇇e|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c⇇b⇇d⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c⇇b⇇d⇇d↫c||génération des données, durée: 1.08 |load données,durée: 0.01
# full_5,period:48 ------
# /!\ L'agent:e est décadent pour la 0-ième fois consécutive; record:4.376744906107585, scores courants:deque([4.220978418986003, 3.1927035649617515, 3.426705996195475], maxlen=3), best_famparams: {'lossCoef_stab': 173.64374999999998, 'lossCoef_ridge': 0.0037209375, 'lossCoef_disHLL': 0.17647349999999992, 'watch_duration': 30}
# , mutations:d⇇f⇇b↫d⇇b↫d⇇f⇇f⇇f↫d⇇f⇇b⇇b↫d⇇f⇇e⇇f⇇e⇇f⇇f⇇e⇇e⇇f|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e⇇d↫e⇇b⇇d⇇b|e⇇f⇇f↫e⇇f⇇c↫e⇇b⇇b⇇f⇇d⇇a⇇f⇇b⇇a↫e⇇b⇇e⇇d↫e⇇b⇇d⇇b↫e||génération des données, durée: 1.04 |load données,durée: 0.01
# full_5,period:49 ----e↗4.4546-
# /!\ L'agent:c est décadent pour la 1-ième fois consécutive; record:4.098498980204265, scores courants:deque([4.098498980204265, 3.654784838358561, 3.6346766153971353], maxlen=3), best_famparams: {'lossCoef_stab': 127.62815624999996, 'lossCoef_ridge': 0.002734889062499999, 'lossCoef_disHLL': 0.27794576249999986, 'watch_duration': 28}
# , mutations:c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c⇇b⇇d⇇d↫c⇇e|f⇇e↫f⇇e⇇e↫f⇇b⇇d⇇b⇇e⇇f⇇e⇇d|c⇇d⇇d↫c⇇b↫c⇇a⇇b⇇c⇇c⇇b⇇f↫c⇇e⇇f⇇a↫c⇇a⇇a⇇a↫c⇇d↫c⇇f⇇f⇇d↫c⇇a↫c⇇f⇇e⇇b↫c⇇b↫c⇇d⇇d⇇d↫c⇇d↫c⇇b⇇d⇇d↫c⇇e↫c|

# %% [markdown]
# ### Historique des `famparams`

# %%
def plot_history_famparams():
    # keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","lossCoef_Laplacian","watch_duration","score"]
    keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","watch_duration","score"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_famparams()

# %% [markdown]
# ### Historique des `loss`

# %%
def plot_history_losses():
    # keys=["loss_stab","loss_disHLL","loss_ridge","loss_Laplacian"]
    keys=["loss_stab","loss_disHLL","loss_ridge",
          "loss_stab*coef","loss_disHLL*coef","loss_ridge*coef",
          "score_l1","score_l2","score_linfty"
          ]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_losses()

# %% [markdown]
# ## Choix d'une des familles

# %%
family_trainer=family_trainers[0]

# %% [markdown]
# ### Valeurs des famparams

# %%
for name,agent_w in family_trainer.agents.items():
    print(name)
    print(agent_w.agent.famparams)
    print(agent_w.agent.agent_score())


best_agent=family_trainer.get_best_agent()
# best_agent=family_trainer.agents['a'].agent
print("best agent")
print(best_agent.famparams)
# print(best_agent.agent_score())
# Out:
# a
# {'lossCoef_stab': 121.55062499999997, 'lossCoef_ridge': 0.0026046562499999993, 'lossCoef_disHLL': 0.12353144999999993, 'watch_duration': 24}
# 4.135944366455078
# b
# {'lossCoef_stab': 85.08543749999997, 'lossCoef_ridge': 0.0039069843749999986, 'lossCoef_disHLL': 0.1852971749999999, 'watch_duration': 30}
# 3.9556808471679688
# c
# {'lossCoef_stab': 85.08543749999998, 'lossCoef_ridge': 0.0039069843749999986, 'lossCoef_disHLL': 0.39706537499999983, 'watch_duration': 26}
# 4.589821815490723
# d
# {'lossCoef_stab': 85.08543749999997, 'lossCoef_ridge': 0.0018232593749999994, 'lossCoef_disHLL': 0.1852971749999999, 'watch_duration': 30}
# 4.007894833882649
# e
# {'lossCoef_stab': 56.723624999999984, 'lossCoef_ridge': 0.005581406249999999, 'lossCoef_disHLL': 0.26471024999999987, 'watch_duration': 28}
# 4.454591433207194
# f
# {'lossCoef_stab': 273.4889062499999, 'lossCoef_ridge': 0.0012762815624999995, 'lossCoef_disHLL': 0.5955980624999997, 'watch_duration': 28}
# 4.651789665222168
# best agent
# {'lossCoef_stab': 56.723624999999984, 'lossCoef_ridge': 0.005581406249999999, 'lossCoef_disHLL': 0.26471024999999987, 'watch_duration': 28}

# %% [markdown]
# ## Testons le long du temps

# %%
def compare_along_the_time(W_val):
    nb_t = len(W_val)
    
    best_agent.load_WY_valid(W_val)
    res_fine_proj,res_HLL,res_model=best_agent.predict()
        
    nb_batch_plot=5
    if nb_batch_plot>W_val.shape[1]:
        nb_batch_plot=W_val.shape[1]
    
    nb_t_plot=3
    #pour avoir le permier temps et le dernier
    t_to_plot=np.floor(np.linspace(0,nb_t-1,nb_t_plot)).astype(int)
    if nb_batch_plot==1:ax=ax[:,tf.newaxis]
    
    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    for i,t in enumerate(t_to_plot):
        for j in range(nb_batch_plot):
            ax[i,j].plot(res_fine_proj[t,j,:,0],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,0],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,0],color="r",label="model")
    ax[0,0].legend()    
    ax[0,0].set_title("Rho")
    fig.tight_layout()


    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    for i,t in enumerate(t_to_plot):
        for j in range(nb_batch_plot):
            ax[i,j].plot(res_fine_proj[t,j,:,2],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,2],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,2],color="r",label="model")
    ax[0,0].legend()    
    ax[0,0].set_title("Energie")
    fig.tight_layout()


    
    
    errors_HLL=tf.reduce_mean(tf.abs(res_fine_proj-res_HLL),axis=[1,2,3])
    errors_model=tf.reduce_mean(tf.abs(res_fine_proj-res_model),axis=[1,2,3])
    
    fig,ax=plt.subplots()
    ax.plot(errors_HLL,color="b",label="HLL")
    ax.plot(errors_model,color="r",label="model")

    # if (np.max(errors_model)>0.1):
    #     ax.set_ylim(0,0.1)
    
    ax.legend()
    ax.set_xlabel("time")

    plt.show()

# %% [markdown]
# ### kind Periodic

# %%
w_init=init_periodic(param,50)
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# traçage de la fonction 'compute_solutions_order1' avec les arguments primitif:
# 		 nb_t,dt_over_dx,dt_over_dx_coarse,nx,nx_coarse,BC_solver,gamma,is_coarse=
# 		 800 0.1 0.009899999999999999 1000 99 periodic 1.4 False
# 		 et le tenseurs W_init de shape: (50, 1000, 3)
# TensorShape([800, 50, 1000, 3])

# %%
compare_along_the_time(W_val)
# Out:
# traçage de la méthode _load_WY_accelerated2 pour les paramètres: W:(800, 50, 1000, 3), nx_ratio:10
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (50, 99, 3)
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False periodic 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (50, 99, 3)

# %% [markdown]
# ### kind non-periodic

# %%
param.BC_model=param.BC_solver=Param.BC_periodic #todo=> reflexive

# %%
w_init=init_non_periodic(param,50)
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([800, 50, 1000, 3])

# %%
compare_along_the_time(W_val)

# %% [markdown]
# ### kind Sod

# %%
def deterministic_SOD(batch_size):
    k=k_tf32
    x = k.arange_float(param.xmin, param.xmax, param.dx)
            
    #La densité peu être assez faible: 0.1 OK, 0.01-> quelques oscilations
    rho_0 =  k.where_float(x < 0.5, 1., 0.5 )+1 #0.125
    #Par contre la pression ne doit pas proche de zéro: avec 0.01 cela craque tout de suite
    P_0 =    k.where_float(x < 0.5, 1., 0.5)+1 #0.1
    P_coefs=np.linspace(1,3,batch_size)

    rho=[rho_0 for _ in range(batch_size)]
    #rho=[rho_0*coef for coef in P_coefs]
    P=np.array([P_0*coef for coef in P_coefs])

    rhoV = k.zeros_float([batch_size, param.nx])
    E=P#/(param.gamma-1)

    return np.stack([rho,rhoV,E],axis=2)

# %%
#w_init=random_SOD(5)
w_init=deterministic_SOD(5)

param.BC_model=param.BC_solver=param.BC_neumann
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([800, 5, 1000, 3])

# %%
compare_along_the_time(W_val)
