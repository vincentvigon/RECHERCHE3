# %% [markdown]
# # Entrainer les agents addi

# %% [markdown]
# ## Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/
# Out:
# /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler

# %%
#ou bien 
#!cp -r drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/* .

# %%
import Euler.core_solver as core
import Euler.agent_addi as aga
import Euler.neural_networks as nn

from Euler.backend import K
from Euler.param import Param,Projecter
from Euler.initial_conditions import GenParam,FuncGenerator

#from Euler.backend import K
import matplotlib.pyplot as plt
import popup_lib.popup as pop
import numpy as np
import copy
import time
# Out:
# Popup loaded!

# %%
param = Param(nx=1000,nx_ratio=10,
              BC_solver=Param.BC_periodic,
              BC_model=Param.BC_periodic)
k_tf32=K("tf",32)
# Out:
# Param initialised with, nx=1000, nx_coarse=99

# %% [markdown]
# ## Génération des données

# %%
def show_w_init(W):
    fig,axs=plt.subplots(3,3,sharex="all",sharey="all",figsize=(6,6))
    axs=axs.flatten()

    for i in range(9):
        axs[i].plot(W[i,:,0],label=r"$\rho$")
        axs[i].plot(W[i,:,1],label=r"$\rho V$")
        axs[i].plot(W[i,:,2],label="$E$")
    plt.legend()
    plt.show()

# %%
genParam=GenParam(param,GenParam.kind_changing)

#paramètres commun à toutes les conditions initiales
genParam.same_discontinuities=True
genParam.initial_speed_factor=0

# %%
generator=FuncGenerator(genParam,param,k_tf32)

# %%
def type_A():
    genParam.batch_size = 100#60

    genParam.kind=GenParam.kind_changing
    genParam.changing_discountMinSpacing= 0.4
    genParam.changing_discountMaxSpacing= 0.8

    genParam.continuousPart_scale = 0.2
    genParam.discontinuousPart_scale =0.2
    return generator.init_W()

show_w_init(type_A())

# %%
def type_B():
    genParam.batch_size = 50
    genParam.kind=GenParam.kind_changing

    genParam.changing_discountMinSpacing= 0.4
    genParam.changing_discountMaxSpacing= 0.8

    genParam.continuousPart_scale = 0.01
    genParam.discontinuousPart_scale =0.3
    return generator.init_W()

show_w_init(type_B())

# %%
def type_C():
    genParam.kind=GenParam.kind_loop
    genParam.batch_size = 100

    genParam.continuousPart_scale = 0.2
    genParam.discontinuousPart_scale =0.2
    return generator.init_W()

show_w_init(type_C())

# %%
#attention, si les random sod vont trop proche de zéro => ça pète
def type_D():
    genParam.batch_size = 50
    genParam.kind=GenParam.kind_random_sod
    return generator.init_W()

show_w_init(type_D())

# %%
#attention, il faut mettre des jeux d'entrainement assez gros pour 
#limiter le hasard du sampling
#Quand, au bout d'une longue stagnation, tous les agents s'améliore d'un coup, c'est suspect ! 
def all_type():
    #return k_tf32.concatenate([type_A(),type_B(),type_C(),type_D()],axis=0)
    return type_A()

w_init=all_type()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
def generate_fine_solutions():
    w_init=all_type()

    #BC_periodic rajoute une discontinuité au bord pour chaque fonction non périodique
    param.BC_model=param.BC_solver=Param.BC_periodic
    return core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val=generate_fine_solutions()
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %% [markdown]
# ## Définition des familles d'agent

# %%
fam_size=6
#un durée pour que les agents puissent tous faire leur 'nb_optimization' optimizations
#attention, cela dépend beaucoup de la watch_duration
period_duration="6 steps"#"15 seconds" 
all_agents=[]

# %%
def family_full(window_size,color):
        name="full_"+str(window_size)
        agents=[]
        model_struct = (32,64,32)
        for _ in range(fam_size):
            agent= aga.Agent_addi(param, nn.Difference_model_tricky(param,window_size,model_struct=model_struct),
                            watch_duration=50, #20
                            lossCoef_stab=50., #10.
                            lossCoef_ridge=3e-3,
                            lossCoef_disHLL=1.,
                            nb_optimization=15,
                            # Si False, le score est calculé sur tous les temps
                            score_computed_last_time=False
                            )
            agents.append(agent)
            all_agents.append(agent)
            
        return pop.Family_trainer(
            agents=agents,
            nb_bestweights_averaged=3,
            nb_strong=3,
            period_duration=period_duration,
            name=name,
            color=color)

family_trainers=[
                 family_full(5,"red"),
                #  family_full(3,"blue"),
                 ]

# %%
def load_data():
    nb_t=800
    ti=time.time()
    W_train = generate_fine_solutions()
    W_val = generate_fine_solutions()
    print(f"|génération des données, durée: {time.time()-ti:.2f} ",end="")
    
    ti=time.time()
    for agent in all_agents:
        agent.load_WY_train(W_train)
        agent.load_WY_valid(W_val)
    print(f"|load données,durée: {time.time()-ti:.2f}",end="")

# %%
try:
    for i in range(50):
        load_data()
        for family_trainer in family_trainers:
            family_trainer.period()
except KeyboardInterrupt:
    for family_trainer in family_trainers:
        #pour pouvoir reprendre si on veut
        family_trainer.interupt_period()
# Out:
# |génération des données, durée: 1.25 traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:5 out of the last 9 calls to <function Agent_addi._load_WY_accelerated at 0x7f02879c2a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7f0287981b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# |load données,durée: 5.35
# full_5,échauffement Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# a↗-infTraçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# b↗0.8285Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:5 out of the last 5 calls to <function Agent_addi._predict_accelerated at 0x7f026e6b8290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:6 out of the last 6 calls to <function Agent_addi._predict_accelerated at 0x7f026e6b8290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# c↗1.004Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:7 out of the last 7 calls to <function Agent_addi._predict_accelerated at 0x7f021c8e00e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:8 out of the last 8 calls to <function Agent_addi._predict_accelerated at 0x7f021c8e00e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# d↗1.0249Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:9 out of the last 9 calls to <function Agent_addi._predict_accelerated at 0x7f020c306170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:10 out of the last 10 calls to <function Agent_addi._predict_accelerated at 0x7f020c306170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# e↗-infTraçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7f02036977a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7f02036977a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# f↗0.9974|génération des données, durée: 1.20 |load données,durée: 3.60
# full_5,period:1 -b↗0.8975c↗1.0629d↗1.0581e↗1.1638f↗1.0641, mutations:a⇇c||génération des données, durée: 1.25 |load données,durée: 3.43
# full_5,period:2 a↗1.1037-c↗1.1174d↗1.0734e↗1.255f↗1.1289, mutations:b⇇f||génération des données, durée: 1.21 |load données,durée: 3.36
# full_5,period:3 a↗1.3067b↗1.231c↗1.2066d↗1.1594e↗1.2882f↗1.3766, mutations:d⇇e||génération des données, durée: 1.12 |load données,durée: 3.31
# full_5,period:4 a↗1.3634b↗1.363c↗1.2674d↗1.3259e↗1.4048f↗1.5141, mutations:c⇇f||génération des données, durée: 1.14 |load données,durée: 3.61
# full_5,period:5 a↗1.4966b↗1.4023c↗1.4179d↗1.4606--, mutations:b⇇f⇇a||génération des données, durée: 1.11 |load données,durée: 3.83
# full_5,period:6 a↗1.9517-c↗1.6059--f↗1.8713, mutations:e⇇f||génération des données, durée: 1.23 |load données,durée: 3.57
# full_5,period:7 a↗2.2628b↗2.0577c↗1.7213-e↗1.5336-, mutations:d⇇e⇇a||génération des données, durée: 1.12 |load données,durée: 3.41
# full_5,period:8 -b↗2.1546c↗1.8069d↗2.0314e↗2.1928f↗1.9266, mutations:c⇇f⇇e||génération des données, durée: 1.18 |load données,durée: 3.65
# full_5,period:9 a↗2.4436b↗2.4901c↗2.2479d↗2.2018e↗2.7075f↗2.1674, mutations:f⇇b||génération des données, durée: 1.39 |load données,durée: 3.40
# full_5,period:10 --c↗2.4275---, mutations:d⇇e⇇a⇇b||génération des données, durée: 1.45 |load données,durée: 3.55
# full_5,period:11 a↗2.5202-c↗2.6877d↗2.5406-f↗2.5075, mutations:b⇇f⇇a⇇e||génération des données, durée: 1.15 |load données,durée: 3.29
# full_5,period:12 a↗2.7023-c↗2.7549d↗2.6062-f↗2.6172, mutations:d⇇e⇇a⇇b⇇e||génération des données, durée: 1.50 |load données,durée: 3.57
# full_5,period:13 ------, mutations:f⇇b⇇a||génération des données, durée: 1.28 |load données,durée: 3.39
# full_5,period:14 ------, mutations:b⇇f⇇a⇇e⇇c||génération des données, durée: 1.14 |load données,durée: 3.82
# full_5,period:15 ---d↗2.6115--, mutations:a⇇c⇇e||génération des données, durée: 1.45 |load données,durée: 3.38
# full_5,period:16 ---d↗2.9012--, mutations:f⇇b⇇a⇇d||génération des données, durée: 1.73 |load données,durée: 3.86
# full_5,period:17 ------, mutations:b⇇f⇇a⇇e⇇c⇇d||génération des données, durée: 1.58 |load données,durée: 3.53
# full_5,period:18 ------, mutations:a⇇c⇇e⇇d||génération des données, durée: 1.18 |load données,durée: 3.28
# full_5,period:19 ------, mutations:f⇇b⇇a⇇d⇇e||génération des données, durée: 1.52 |load données,durée: 3.82
# full_5,period:20 ------, mutations:c⇇f⇇e⇇a||génération des données, durée: 1.20 |load données,durée: 3.52
# full_5,period:21 ------, mutations:e⇇f⇇a||génération des données, durée: 1.25 |load données,durée: 3.62
# full_5,period:22 -b↗2.5639----, mutations:f⇇b⇇a⇇d⇇e⇇e||génération des données, durée: 1.13 |load données,durée: 3.58
# full_5,period:23 ----e↗2.9827-, mutations:c⇇f⇇e⇇a⇇e||génération des données, durée: 1.28 |load données,durée: 3.50
# full_5,period:24 ------, mutations:b⇇f⇇a⇇e⇇c⇇d⇇d||génération des données, durée: 1.12 |load données,durée: 3.55
# full_5,period:25 -b↗2.6847----, mutations:f⇇b⇇a⇇d⇇e⇇e⇇e||génération des données, durée: 1.20 |load données,durée: 3.38
# full_5,period:26 ------
# /!\ L'agent:e est décadent; record:2.9827077388763428, scores courants:deque([-inf, -inf, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 112.5, 'lossCoef_ridge': 0.0014699999999999997, 'lossCoef_disHLL': 0.48999999999999994, 'watch_duration': 50}
# , mutations:e⇇f⇇a⇇a||génération des données, durée: 1.11 |load données,durée: 3.27
# full_5,period:27 ------, mutations:d⇇e⇇a⇇b⇇e⇇e||génération des données, durée: 1.20 |load données,durée: 3.54
# full_5,period:28 ------, mutations:a⇇c⇇e⇇d⇇c||génération des données, durée: 1.12 |load données,durée: 3.51
# full_5,period:29 -b↗2.7019---f↗2.8981, mutations:c⇇f⇇e⇇a⇇e⇇e||génération des données, durée: 1.11 |load données,durée: 3.46
# full_5,period:30 ------, mutations:b⇇f⇇a⇇e⇇c⇇d⇇d⇇e||génération des données, durée: 1.22 |load données,durée: 3.27
# full_5,period:31 ------, mutations:a⇇c⇇e⇇d⇇c⇇d||génération des données, durée: 1.41 |load données,durée: 3.87
# full_5,period:32 ------, mutations:f⇇b⇇a⇇d⇇e⇇e⇇e⇇d||génération des données, durée: 1.52 |load données,durée: 3.60
# full_5,period:33 -b↗2.7192----
# /!\ L'agent:e est décadent; record:2.9827077388763428, scores courants:deque([0.48641074, -inf, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 112.5, 'lossCoef_ridge': 0.0014699999999999997, 'lossCoef_disHLL': 0.48999999999999994, 'watch_duration': 50}
# , mutations:e⇇f⇇a⇇a⇇c||génération des données, durée: 1.15 |load données,durée: 3.26
# full_5,period:34 ------, mutations:a⇇c⇇e⇇d⇇c⇇d⇇d||génération des données, durée: 1.12 |load données,durée: 3.57
# full_5,period:35 a↗2.8832----f↗2.9982, mutations:c⇇f⇇e⇇a⇇e⇇e⇇f||génération des données, durée: 1.39 |load données,durée: 3.73
# full_5,period:36 --c↗2.7665---, mutations:b⇇f⇇a⇇e⇇c⇇d⇇d⇇e⇇e||génération des données, durée: 1.11 |load données,durée: 3.38
# full_5,period:37 ------, mutations:d⇇e⇇a⇇b⇇e⇇e⇇f||génération des données, durée: 1.20 |load données,durée: 3.61
# full_5,period:38 ------
# /!\ L'agent:f est décadent; record:2.9982359409332275, scores courants:deque([-inf, 2.639262, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 78.75, 'lossCoef_ridge': 0.0010289999999999997, 'lossCoef_disHLL': 1.575, 'watch_duration': 52}
# , mutations:f⇇b⇇a⇇d⇇e⇇e⇇e⇇d⇇d||génération des données, durée: 1.70 |load données,durée: 3.46
# full_5,period:39 ------, mutations:e⇇f⇇a⇇a⇇c⇇a||génération des données, durée: 1.39 |load données,durée: 3.50
# full_5,period:40 ------, mutations:a⇇c⇇e⇇d⇇c⇇d⇇d⇇e||génération des données, durée: 1.19 |load données,durée: 3.61
# full_5,period:41 ------, mutations:b⇇f⇇a⇇e⇇c⇇d⇇d⇇e⇇e⇇e||génération des données, durée: 1.16 |load données,durée: 3.52
# full_5,period:42 -b↗2.7296----, mutations:c⇇f⇇e⇇a⇇e⇇e⇇f⇇e||génération des données, durée: 1.33 |load données,durée: 3.90
# full_5,period:43 ------, mutations:e⇇f⇇a⇇a⇇c⇇a⇇f||génération des données, durée: 1.13 |load données,durée: 3.45
# full_5,period:44 ------
# /!\ L'agent:f est décadent; record:2.9982359409332275, scores courants:deque([-inf, -inf, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 78.75, 'lossCoef_ridge': 0.0010289999999999997, 'lossCoef_disHLL': 1.575, 'watch_duration': 52}
# , mutations:f⇇b⇇a⇇d⇇e⇇e⇇e⇇d⇇d⇇a||génération des données, durée: 1.28 |load données,durée: 3.43
# full_5,period:45 --c↗2.8297---, mutations:a⇇c⇇e⇇d⇇c⇇d⇇d⇇e⇇e||génération des données, durée: 1.17 |load données,durée: 3.67
# full_5,period:46 ------, mutations:e⇇f⇇a⇇a⇇c⇇a⇇f⇇d||génération des données, durée: 1.22 |load données,durée: 3.60
# full_5,period:47 ------, mutations:b⇇f⇇a⇇e⇇c⇇d⇇d⇇e⇇e⇇e⇇e||génération des données, durée: 1.31 |load données,durée: 3.50
# full_5,period:48 ------, mutations:a⇇c⇇e⇇d⇇c⇇d⇇d⇇e⇇e⇇f||génération des données, durée: 1.51 |load données,durée: 3.50
# full_5,period:49 ------, mutations:e⇇f⇇a⇇a⇇c⇇a⇇f⇇d⇇d|

# %% [markdown]
# ### Historique des `famparams`

# %%
def plot_history_famparams():
    # keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","lossCoef_Laplacian","watch_duration","score"]
    keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","watch_duration","score"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_famparams()

# %% [markdown]
# ### Historique des trois `loss`

# %%
def plot_history_losses():
    # keys=["loss_stab","loss_disHLL","loss_ridge","loss_Laplacian"]
    keys=["loss_stab","loss_disHLL","loss_ridge"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_losses()

# %% [markdown]
# ### comparaison à l'oeil des famparams

# %%
import tensorflow as tf
family_trainer=family_trainers[0]

for name,agent_w in family_trainer.agents.items():
    print(name)
    print(agent_w.agent.famparams)
    print(agent_w.agent.agent_score())


best_agent=family_trainer.get_best_agent()
# best_agent=family_trainer.agents['a'].agent
print("best agent")
print(best_agent.famparams)
# print(best_agent.agent_score())
# Out:
# a
# {'lossCoef_stab': 118.125, 'lossCoef_ridge': 0.0007202999999999998, 'lossCoef_disHLL': 2.3625, 'watch_duration': 54}
# 2.748621
# b
# {'lossCoef_stab': 168.75, 'lossCoef_ridge': 0.0010289999999999997, 'lossCoef_disHLL': 0.7349999999999999, 'watch_duration': 52}
# nan
# c
# {'lossCoef_stab': 78.75, 'lossCoef_ridge': 0.0010289999999999997, 'lossCoef_disHLL': 0.7349999999999999, 'watch_duration': 48}
# 2.5993276
# d
# {'lossCoef_stab': 55.125, 'lossCoef_ridge': 0.0015434999999999997, 'lossCoef_disHLL': 1.1024999999999998, 'watch_duration': 54}
# 2.5784934
# e
# {'lossCoef_stab': 168.75, 'lossCoef_ridge': 0.0022049999999999995, 'lossCoef_disHLL': 1.575, 'watch_duration': 52}
# 2.7719054
# f
# {'lossCoef_stab': 118.125, 'lossCoef_ridge': 0.0033074999999999992, 'lossCoef_disHLL': 1.1024999999999998, 'watch_duration': 54}
# 2.5491683
# best agent
# {'lossCoef_stab': 118.125, 'lossCoef_ridge': 0.0033074999999999992, 'lossCoef_disHLL': 1.1024999999999998, 'watch_duration': 54}

# %% [markdown]
# ## Testons sur le jeu "loop" (périodique)

# %% [markdown]
# ## Testons le long du temps

# %%
def compare_along_the_time(W_val):
    nb_t = len(W_val)
    
    best_agent.load_WY_valid(W_val)
    res_fine_proj,res_HLL,res_model=best_agent.predict()
        
    nb_batch_plot=5
    if nb_batch_plot>W_val.shape[1]:
        nb_batch_plot=W_val.shape[1]
    
    nb_t_plot=6
    #pour avoir le permier temps et le dernier
    t_to_plot=np.floor(np.linspace(0,nb_t-1,nb_t_plot)).astype(int)
    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    if nb_batch_plot==1:ax=ax[:,tf.newaxis]
    
    for i,t in enumerate(t_to_plot):
        for j in range(nb_batch_plot):
            ax[i,j].plot(res_fine_proj[t,j,:,0],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,0],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,0],"r",label="model")
    ax[0,0].legend()    

    fig.tight_layout()
    
    errors_HLL=tf.reduce_mean(tf.abs(res_fine_proj-res_HLL),axis=[1,2,3])
    errors_model=tf.reduce_mean(tf.abs(res_fine_proj-res_model),axis=[1,2,3])
    
    fig,ax=plt.subplots()
    ax.plot(errors_HLL,label="HLL")
    ax.plot(errors_model,label="model")

    if (np.max(errors_model)>0.1):
        ax.set_ylim(0,0.1)
    
    ax.legend()
    ax.set_xlabel("time")

    plt.show()

# %% [markdown]
# ### kind Loop

# %%
genParam.kind=GenParam.kind_loop
generator=FuncGenerator(genParam,param,k_tf32)
w_init=generator.init_W()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
param.BC_model=param.BC_solver=Param.BC_periodic
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %%
compare_along_the_time(W_val)

# %% [markdown]
# ### kind changing

# %%
genParam.kind=GenParam.kind_changing
generator=FuncGenerator(genParam,param,k_tf32)
w_init=generator.init_W()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
param.BC_model=param.BC_solver=Param.BC_reflexive
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %%
compare_along_the_time(W_val)

# %% [markdown]
# ### kind Sod

# %%
def generate_Riemann_Problem(batch_size):
    k = k_tf32
    res = np.zeros([batch_size, param.nx])
    for i in range(batch_size):
        w_left = 0.5 + np.random.random()
        w_right = 0.5 + np.random.random()
        res[i, :param.nx // 2] = max(w_left, w_right)
        res[i, param.nx // 2:] = min(w_left, w_right)
    return k.convert(res)
A=generate_Riemann_Problem(5)
A.shape
# Out:
# TensorShape([5, 1000])

# %%
def deterministic_SOD(batch_size):
    k=k_tf32
    x = k.arange_float(param.xmin, param.xmax, param.dx)
            
    #La densité peu être assez faible: 0.1 OK, 0.01-> quelques oscilations
    rho_0 =  k.where_float(x < 0.5, 1., 0.5) 
    #Par contre la pression ne doit pas proche de zéro: avec 0.01 cela craque tout de suite
    P_0 =    k.where_float(x < 0.5, 1., 0.5)   

    P_coefs=np.linspace(1,10,batch_size)

    rho=[rho_0 for _ in range(batch_size)]
    P=[P_0*coef for coef in P_coefs]
    rhoV = k.zeros_float([batch_size, param.nx])

    return np.stack([rho,rhoV,P],axis=2)

# %%
def random_SOD(batch_size):
    k=k_tf32
    rho = generate_Riemann_Problem(batch_size)
    P = generate_Riemann_Problem(batch_size) #* (param.gamma - 1)
    rhoV = k.zeros_float([batch_size, param.nx])
    return np.stack([rho,rhoV,P],axis=2)

# %%
#w_init=random_SOD(5)
w_init=deterministic_SOD(5)

nb_t=2000
param.BC_model=param.BC_solver=param.BC_neumann
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([2000, 5, 1000, 3])

# %%
compare_along_the_time(W_val)
# Out:
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False

# %% [markdown]
# ### Kind random Sod

# %%
genParam.kind=GenParam.kind_random_sod
generator=FuncGenerator(genParam,param,k_tf32)
w_init=generator.init_W()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
param.BC_model=param.BC_solver=Param.BC_neumann
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %%
compare_along_the_time(W_val)
