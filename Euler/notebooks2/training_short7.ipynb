# %% [markdown]
# # Entrainer les agents addi

# %% [markdown]
# ## Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %reset -f

# %%
# %cd /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/
# Out:
# /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler

# %%
#ou bien 
#!cp -r drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/* .

# %%
import Euler.core_solver as core
import Euler.agent_addi as aga
import Euler.neural_networks as nn

from Euler.backend import K
from Euler.param import Param,Projecter
from Euler.initial_conditions import *

#from Euler.backend import K
import matplotlib.pyplot as plt
import popup_lib.popup as pop
import numpy as np
import copy
import time
# Out:
# Popup loaded!

# %%
param = Param(nx=1000,nx_ratio=10,
              BC_solver=Param.BC_periodic,
              BC_model=Param.BC_periodic)
k_tf32=K("tf",32)
# Out:
# Param initialised with, nx=1000, nx_coarse=99

# %% [markdown]
# ## Génération des données

# %%
def show_w_init(W):
    fig,axs=plt.subplots(3,3,sharex="all",sharey="all",figsize=(6,6))
    axs=axs.flatten()

    for i in range(9):
        axs[i].plot(W[i,:,0],label=r"$\rho$")
        axs[i].plot(W[i,:,1],label=r"$\rho V$")
        axs[i].plot(W[i,:,2],label="$E$")
    plt.legend()
    plt.show()

# %%
genParam=GenParam(param,GenParam.kind_changing)

#paramètres commun à toutes les conditions initiales
genParam.same_discontinuities=True
genParam.initial_speed_factor=0.5

# %%
generator=FuncGenerator(genParam,param,k_tf32)

# %%
def type_A():
    genParam.batch_size = 150#60

    genParam.kind=GenParam.kind_changing
    genParam.changing_discountMinSpacing= 0.4
    genParam.changing_discountMaxSpacing= 0.8

    genParam.continuousPart_scale = 0.2
    genParam.discontinuousPart_scale =0.2
    return generator.init_W()

show_w_init(type_A())

# %%
def type_B():
    genParam.batch_size = 50
    genParam.kind=GenParam.kind_changing

    genParam.changing_discountMinSpacing= 0.4
    genParam.changing_discountMaxSpacing= 0.8

    genParam.continuousPart_scale = 0.01
    genParam.discontinuousPart_scale =0.3
    return generator.init_W()

show_w_init(type_B())

# %%
def type_C():
    genParam.kind=GenParam.kind_loop
    genParam.batch_size = 100

    genParam.continuousPart_scale = 0.2
    genParam.discontinuousPart_scale =0.2
    return generator.init_W()

show_w_init(type_C())

# %%
#attention, si les random sod vont trop proche de zéro => ça pète
def type_D():
    return init_random_sod(param, batch_size=50, k=k_tf32, minimum_E=0.05, maximal_jump_E=2, minimum_rho=0.05, maximal_jump_rho=2)

show_w_init(type_D())

# %%
#attention, il faut mettre des jeux d'entrainement assez gros pour 
#limiter le hasard du sampling
#Quand, au bout d'une longue stagnation, tous les agents s'améliore d'un coup, c'est suspect ! 
def all_type():
    #return k_tf32.concatenate([type_A(),type_B(),type_C(),type_D()],axis=0)
    return type_A()

w_init=all_type()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
def generate_fine_solutions():
    w_init=all_type()

    #BC_periodic rajoute une discontinuité au bord pour chaque fonction non périodique
    param.BC_model=param.BC_solver=Param.BC_periodic
    return core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val=generate_fine_solutions()
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %% [markdown]
# ## Entrainement

# %% [markdown]
# ### Définition des familles d'agent

# %%
fam_size=6
#un durée pour que les agents puissent tous faire leur 'nb_optimization' optimizations
#attention, cela dépend beaucoup de la watch_duration
period_duration="6 steps"#"15 seconds" 
all_agents=[]

# %%
def family_full(window_size,color):
        name="full_"+str(window_size)
        agents=[]
        model_struct = (32,64,32)
        for _ in range(fam_size):
            model=nn.Difference_model_tricky(
                param,
                window_size,
                censure=False,
                model_struct=model_struct)
            
            model.toggle_tricky_kernel_trainable(False)
            
            agent= aga.Agent_addi(param, 
                            model,
                            watch_duration=50, #20
                            lossCoef_stab=100., #10.
                            lossCoef_ridge=3e-3,
                            lossCoef_disHLL=1.,
                            nb_optimization=15,
                            watch_duration_for_val=0.1 #si <1, c'est une proportion
                            )
            agents.append(agent)
            all_agents.append(agent)
            
        return pop.Family_trainer(
            agents=agents,
            nb_bestweights_averaged=3,
            nb_strong=3,
            period_duration=period_duration,
            name=name,
            color=color)

family_trainers=[
                 family_full(5,"red"),
                #  family_full(3,"blue"),
                 ]

# %%
def load_data():
    ti=time.time()
    W_train = generate_fine_solutions()
    W_val = generate_fine_solutions()
    print(f"|génération des données, durée: {time.time()-ti:.2f} ",end="")
    
    ti=time.time()
    for agent in all_agents:
        agent.load_WY_train(W_train)
        agent.load_WY_valid(W_val)
    print(f"|load données,durée: {time.time()-ti:.2f}",end="")

# %% [markdown]
# ### LA BOUCLE

# %%
try:
    for i in range(50):
        load_data()
        for family_trainer in family_trainers:
            family_trainer.period()
except KeyboardInterrupt:
    for family_trainer in family_trainers:
        #pour pouvoir reprendre si on veut
        family_trainer.interupt_period()
# Out:
# |génération des données, durée: 1.16 traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:5 out of the last 9 calls to <function Agent_addi._load_WY_accelerated at 0x7fcbbf2ff9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _load_WY_accelerated
# WARNING:tensorflow:6 out of the last 11 calls to <function Agent_addi._load_WY_accelerated at 0x7fcc3a335b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# |load données,durée: 3.46
# full_5,échauffement Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# a↗1.0562Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# b↗1.041Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# c↗1.0612Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# d↗1.0432Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# e↗1.0646Traçage de la méthode gradient_tape
# Traçage de la méthode gradient_tape
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# f↗1.0547|génération des données, durée: 1.08 |load données,durée: 2.85
# full_5,period:1 a↗1.1395b↗1.123c↗1.1801d↗1.132e↗1.1406f↗1.1355, mutations:b⇇e||génération des données, durée: 1.08 |load données,durée: 2.99
# full_5,period:2 a↗1.2583b↗1.1988c↗1.3707d↗1.254e↗1.2368f↗1.2479, mutations:b⇇e⇇c||génération des données, durée: 1.08 |load données,durée: 2.91
# full_5,period:3 a↗1.4351b↗1.4295c↗1.703d↗1.4752e↗1.3885f↗1.4675, mutations:e⇇c||génération des données, durée: 1.08 |load données,durée: 2.83
# full_5,period:4 a↗1.5817b↗1.6455c↗1.8519d↗1.6716e↗1.8309f↗1.6449, mutations:a⇇e||génération des données, durée: 1.08 |load données,durée: 2.91
# full_5,period:5 a↗1.9158b↗1.7537c↗1.8906d↗1.8137e↗1.9764f↗1.79, mutations:b⇇e⇇c⇇c||génération des données, durée: 1.08 |load données,durée: 2.86
# full_5,period:6 ------, mutations:f⇇a||génération des données, durée: 1.08 |load données,durée: 2.88
# full_5,period:7 a↗2.1169-c↗2.0566d↗2.0039e↗2.136f↗2.1004, mutations:b⇇e⇇c⇇c⇇a||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:8 -b↗2.0581----, mutations:d⇇a||génération des données, durée: 1.08 |load données,durée: 2.84
# full_5,period:9 -b↗2.0763-d↗2.0429-f↗2.1091, mutations:c⇇a||génération des données, durée: 1.08 |load données,durée: 2.86
# full_5,period:10 ------, mutations:a⇇e⇇f||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:11 ------, mutations:d⇇a⇇f||génération des données, durée: 1.10 |load données,durée: 2.92
# full_5,period:12 ------, mutations:c⇇a⇇a||génération des données, durée: 1.08 |load données,durée: 2.86
# full_5,period:13 a↗2.2378b↗2.2546c↗2.1793d↗2.1543e↗2.1676f↗2.2485, mutations:d⇇a⇇f⇇f||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:14 ------, mutations:e⇇c⇇b||génération des données, durée: 1.07 |load données,durée: 2.85
# full_5,period:15 ---d↗2.1627--, mutations:c⇇a⇇a⇇f||génération des données, durée: 1.09 |load données,durée: 2.85
# full_5,period:16 -b↗2.2834c↗2.1883d↗2.3542-f↗2.2488, mutations:a⇇e⇇f⇇b||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:17 -----f↗2.2657, mutations:e⇇c⇇b⇇f||génération des données, durée: 1.08 |load données,durée: 2.97
# full_5,period:18 ----e↗2.2477-, mutations:c⇇a⇇a⇇f⇇f||génération des données, durée: 1.09 |load données,durée: 2.83
# full_5,period:19 ------, mutations:a⇇e⇇f⇇b⇇b||génération des données, durée: 1.08 |load données,durée: 2.88
# full_5,period:20 ------, mutations:f⇇a⇇b||génération des données, durée: 1.07 |load données,durée: 2.85
# full_5,period:21 ------, mutations:c⇇a⇇a⇇f⇇f⇇d||génération des données, durée: 1.08 |load données,durée: 2.84
# full_5,period:22 --c↗2.2399-e↗2.2761-, mutations:a⇇e⇇f⇇b⇇b⇇b||génération des données, durée: 1.07 |load données,durée: 2.87
# full_5,period:23 -b↗2.2974c↗2.3286-e↗2.3612-, mutations:f⇇a⇇b⇇c||génération des données, durée: 1.09 |load données,durée: 2.83
# full_5,period:24 ------, mutations:a⇇e⇇f⇇b⇇b⇇b⇇e||génération des données, durée: 1.08 |load données,durée: 2.85
# full_5,period:25 ------, mutations:b⇇e⇇c⇇c⇇a⇇d||génération des données, durée: 1.07 |load données,durée: 2.87
# full_5,period:26 a↗2.3446-c↗2.3892-e↗2.3789f↗2.3859, mutations:d⇇a⇇f⇇f⇇e||génération des données, durée: 1.08 |load données,durée: 2.86
# full_5,period:27 a↗2.4379b↗2.342c↗2.482d↗2.432e↗2.4586f↗2.4709, mutations:b⇇e⇇c⇇c⇇a⇇d⇇c||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:28 ------, mutations:d⇇a⇇f⇇f⇇e⇇f||génération des données, durée: 1.08 |load données,durée: 2.86
# full_5,period:29 a↗2.49b↗2.5496c↗2.534d↗2.4857-f↗2.565, mutations:e⇇c⇇b⇇f⇇f||génération des données, durée: 1.08 |load données,durée: 2.85
# full_5,period:30 ------, mutations:d⇇a⇇f⇇f⇇e⇇f⇇c||génération des données, durée: 1.08 |load données,durée: 2.83
# full_5,period:31 a↗2.5496b↗2.5911c↗2.5486d↗2.5253e↗2.5362f↗2.5878, mutations:d⇇a⇇f⇇f⇇e⇇f⇇c⇇b||génération des données, durée: 1.07 |load données,durée: 2.84
# full_5,period:32 ------, mutations:e⇇c⇇b⇇f⇇f⇇b||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:33 a↗2.5762b↗2.6126-d↗2.5355--, mutations:c⇇a⇇a⇇f⇇f⇇d⇇b||génération des données, durée: 1.07 |load données,durée: 2.83
# full_5,period:34 ------, mutations:d⇇a⇇f⇇f⇇e⇇f⇇c⇇b⇇b||génération des données, durée: 1.08 |load données,durée: 2.85
# full_5,period:35 -b↗2.6334c↗2.5702d↗2.5953e↗2.5571f↗2.6531, mutations:e⇇c⇇b⇇f⇇f⇇b⇇b||génération des données, durée: 1.08 |load données,durée: 2.92
# full_5,period:36 ------, mutations:a⇇e⇇f⇇b⇇b⇇b⇇e⇇b||génération des données, durée: 1.09 |load données,durée: 2.85
# full_5,period:37 ------, mutations:c⇇a⇇a⇇f⇇f⇇d⇇b⇇f||génération des données, durée: 1.08 |load données,durée: 2.88
# full_5,period:38 ------, mutations:d⇇a⇇f⇇f⇇e⇇f⇇c⇇b⇇b⇇b||génération des données, durée: 1.09 |load données,durée: 2.87
# full_5,period:39 ------, mutations:a⇇e⇇f⇇b⇇b⇇b⇇e⇇b⇇f||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:40 ------, mutations:c⇇a⇇a⇇f⇇f⇇d⇇b⇇f⇇b||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:41 -b↗2.6441--e↗2.5814-, mutations:d⇇a⇇f⇇f⇇e⇇f⇇c⇇b⇇b⇇b⇇b||génération des données, durée: 1.09 |load données,durée: 2.85
# full_5,period:42 a↗2.6448b↗2.6681c↗2.6228d↗2.6644e↗2.6292f↗2.6799, mutations:e⇇c⇇b⇇f⇇f⇇b⇇b⇇b||génération des données, durée: 1.07 |load données,durée: 2.90
# full_5,period:43 ------, mutations:c⇇a⇇a⇇f⇇f⇇d⇇b⇇f⇇b⇇b||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:44 ------, mutations:a⇇e⇇f⇇b⇇b⇇b⇇e⇇b⇇f⇇f||génération des données, durée: 1.08 |load données,durée: 2.86
# full_5,period:45 ------, mutations:e⇇c⇇b⇇f⇇f⇇b⇇b⇇b⇇f||génération des données, durée: 1.08 |load données,durée: 2.90
# full_5,period:46 ------, mutations:c⇇a⇇a⇇f⇇f⇇d⇇b⇇f⇇b⇇b⇇b||génération des données, durée: 1.08 |load données,durée: 2.87
# full_5,period:47 --c↗2.633--f↗2.6812, mutations:a⇇e⇇f⇇b⇇b⇇b⇇e⇇b⇇f⇇f⇇b||génération des données, durée: 1.08 |load données,durée: 2.89
# full_5,period:48 ------, mutations:e⇇c⇇b⇇f⇇f⇇b⇇b⇇b⇇f⇇b||génération des données, durée: 1.08 |load données,durée: 2.92
# full_5,period:49 ------, mutations:c⇇a⇇a⇇f⇇f⇇d⇇b⇇f⇇b⇇b⇇b⇇d|

# %% [markdown]
# ### Historique des `famparams`

# %%
def plot_history_famparams():
    # keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","lossCoef_Laplacian","watch_duration","score"]
    keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","watch_duration","score"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_famparams()

# %% [markdown]
# ### Historique des trois `loss`

# %%
def plot_history_losses():
    # keys=["loss_stab","loss_disHLL","loss_ridge","loss_Laplacian"]
    keys=["loss_stab","loss_disHLL","loss_ridge"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_losses()

# %% [markdown]
# ### Valeurs des famparams

# %%
import tensorflow as tf
family_trainer=family_trainers[0]

for name,agent_w in family_trainer.agents.items():
    print(name)
    print(agent_w.agent.famparams)
    print(agent_w.agent.agent_score())


best_agent=family_trainer.get_best_agent()
# best_agent=family_trainer.agents['a'].agent
print("best agent")
print(best_agent.famparams)
# print(best_agent.agent_score())
# Out:
# a
# {'lossCoef_stab': 186.046875, 'lossCoef_ridge': 0.0005294204999999998, 'lossCoef_disHLL': 1.7364374999999996, 'watch_duration': 44}
# 2.5524356
# b
# {'lossCoef_stab': 265.78125, 'lossCoef_ridge': 0.0007563149999999998, 'lossCoef_disHLL': 1.1576249999999997, 'watch_duration': 46}
# 2.5860624
# c
# {'lossCoef_stab': 598.0078125, 'lossCoef_ridge': 0.0007941307499999997, 'lossCoef_disHLL': 0.5672362499999998, 'watch_duration': 50}
# 2.5929463
# d
# {'lossCoef_stab': 398.671875, 'lossCoef_ridge': 0.0005294204999999998, 'lossCoef_disHLL': 0.8103374999999997, 'watch_duration': 48}
# 2.6017876
# e
# {'lossCoef_stab': 398.671875, 'lossCoef_ridge': 0.0011344724999999998, 'lossCoef_disHLL': 0.8103374999999997, 'watch_duration': 48}
# 2.5634246
# f
# {'lossCoef_stab': 265.78125, 'lossCoef_ridge': 0.0007563149999999998, 'lossCoef_disHLL': 1.1576249999999997, 'watch_duration': 50}
# 2.5420043
# best agent
# {'lossCoef_stab': 265.78125, 'lossCoef_ridge': 0.0007563149999999998, 'lossCoef_disHLL': 1.1576249999999997, 'watch_duration': 50}

# %% [markdown]
# ## Testons le long du temps

# %%
def compare_along_the_time(W_val):
    nb_t = len(W_val)
    
    best_agent.load_WY_valid(W_val)
    res_fine_proj,res_HLL,res_model=best_agent.predict()
        
    nb_batch_plot=5
    if nb_batch_plot>W_val.shape[1]:
        nb_batch_plot=W_val.shape[1]
    
    nb_t_plot=6
    #pour avoir le permier temps et le dernier
    t_to_plot=np.floor(np.linspace(0,nb_t-1,nb_t_plot)).astype(int)
    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    if nb_batch_plot==1:ax=ax[:,tf.newaxis]
    
    for i,t in enumerate(t_to_plot):
        for j in range(nb_batch_plot):
            ax[i,j].plot(res_fine_proj[t,j,:,0],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,0],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,0],"r",label="model")
    ax[0,0].legend()    

    fig.tight_layout()
    
    errors_HLL=tf.reduce_mean(tf.abs(res_fine_proj-res_HLL),axis=[1,2,3])
    errors_model=tf.reduce_mean(tf.abs(res_fine_proj-res_model),axis=[1,2,3])
    
    fig,ax=plt.subplots()
    ax.plot(errors_HLL,label="HLL")
    ax.plot(errors_model,label="model")

    # if (np.max(errors_model)>0.1):
    #     ax.set_ylim(0,0.1)
    
    ax.legend()
    ax.set_xlabel("time")

    plt.show()

# %% [markdown]
# ### kind Loop

# %%
genParam.kind=GenParam.kind_loop
generator=FuncGenerator(genParam,param,k_tf32)
w_init=generator.init_W()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
param.BC_model=param.BC_solver=Param.BC_periodic
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %%
compare_along_the_time(W_val)

# %% [markdown]
# ### kind changing

# %%
genParam.kind=GenParam.kind_changing
generator=FuncGenerator(genParam,param,k_tf32)
w_init=generator.init_W()
w_init.shape
# Out:
# TensorShape([100, 1000, 3])

# %%
nb_t=1000
param.BC_model=param.BC_solver=Param.BC_reflexive
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([1000, 100, 1000, 3])

# %%
compare_along_the_time(W_val)

# %% [markdown]
# ### kind Sod

# %%
def generate_Riemann_Problem(batch_size):
    k = k_tf32
    res = np.zeros([batch_size, param.nx])
    for i in range(batch_size):
        w_left = 0.5 + np.random.random()
        w_right = 0.5 + np.random.random()
        res[i, :param.nx // 2] = max(w_left, w_right)
        res[i, param.nx // 2:] = min(w_left, w_right)
    return k.convert(res)
A=generate_Riemann_Problem(5)
A.shape
# Out:
# TensorShape([5, 1000])

# %%
def deterministic_SOD(batch_size):
    k=k_tf32
    x = k.arange_float(param.xmin, param.xmax, param.dx)
            
    #La densité peu être assez faible: 0.1 OK, 0.01-> quelques oscilations
    rho_0 =  k.where_float(x < 0.5, 1., 0.5 ) #0.125
    #Par contre la pression ne doit pas proche de zéro: avec 0.01 cela craque tout de suite
    P_0 =    k.where_float(x < 0.5, 1., 0.5)   #0.1

    P_coefs=np.linspace(1,10,batch_size)

    rho=[rho_0 for _ in range(batch_size)]
    #rho=[rho_0*coef for coef in P_coefs]
    P=[P_0*coef for coef in P_coefs]
    rhoV = k.zeros_float([batch_size, param.nx])

    return np.stack([rho,rhoV,P],axis=2)

# %%
#w_init=random_SOD(5)
w_init=deterministic_SOD(5)

nb_t=1000
param.BC_model=param.BC_solver=param.BC_neumann
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([2000, 5, 1000, 3])

# %%
compare_along_the_time(W_val)
# Out:
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False

# %% [markdown]
# ### Kind random Sod

# %%
w_init=init_random_sod(param, batch_size=50, k=k_tf32, minimum_E=0.05, maximal_jump_E=2, minimum_rho=0.05, maximal_jump_rho=2)
w_init.shape
# Out:
# TensorShape([50, 1000, 3])

# %%
nb_t=1000
param.BC_model=param.BC_solver=Param.BC_neumann
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([1000, 50, 1000, 3])

# %%
compare_along_the_time(W_val)
# Out:
# traçage de la méthode _load_WY_accelerated
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': True
# traçage de la méthode _predict_accelerated, pour l'estimation 'is_model?': False
# WARNING:tensorflow:5 out of the last 5417 calls to <function Agent_addi._predict_accelerated at 0x7fc80df29f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
