# %% [markdown]
# # Entrainer les agents addi

# %% [markdown]
# ## Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %reset -f

# %%
# %cd /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/
# Out:
# /content/drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler

# %%
#ou bien 
#!cp -r drive/MyDrive/permanent/RECHERCHE2/ml_flux_euler/* .

# %%
import Euler.core_solver as core
import Euler.agent_addi as aga
import Euler.neural_networks as nn

from Euler.backend import K
from Euler.param import Param,Projecter
from Euler.initial_conditions import *

#from Euler.backend import K
import matplotlib.pyplot as plt
import popup_lib.popup as pop
import numpy as np
import copy
import time

import tensorflow as tf
# Out:
# Popup loaded!

# %% [markdown]
# Attention: `BC_periodic` rajoute une discontinuité au bord pour chaque fonction non périodique.

# %%
param = Param(nx=1000,nx_ratio=10,
              BC_solver=Param.BC_reflexive,
              BC_model=Param.BC_reflexive)
nb_t=800
k_tf32=K("tf",32)
# Out:
# Param initialised with, nx=1000, nx_coarse=99

# %% [markdown]
# ## Génération des données

# %%
def show_w_init(W):
    fig,axs=plt.subplots(3,3,sharex="all",sharey="all",figsize=(6,6))
    axs=axs.flatten()

    for i in range(9):
        axs[i].plot(W[i,:,0],label=r"$\rho$")
        axs[i].plot(W[i,:,1],label=r"$\rho V$")
        axs[i].plot(W[i,:,2],label="$E$")
    plt.legend()
    plt.show()

# %%
res=init_non_periodic(param,9)
print(res.shape)
show_w_init(res)
# Out:
# (9, 1000, 3)

# %%
res=init_periodic(param,9)
print(res.shape)
show_w_init(res)
# Out:
# (9, 1000, 3)

# %%
#attention, si les random sod vont trop proche de zéro => ça pète
res= init_random_sod(param, batch_size=10, minimum_E=0.05, maximal_jump_E=2, minimum_rho=0.05, maximal_jump_rho=2)
print(res.shape)
show_w_init(res)
# Out:
# (10, 1000, 3)

# %% [markdown]
# * Il faut mettre des jeux d'entrainement assez gros pour limiter le hasard du sampling
# * Quand, au bout d'une longue stagnation, tous les agents s'améliore d'un coup, c'est suspect !
# * On ne peut pas mettre non plus des batchs trop gros à cause de la limite des GPU;  cela bloque très vite ex de jeu qui passe pas:
#
#         nb_t=1000, batch_size = 140, nx=1000.

# %%
def data_for_train():
    return init_non_periodic(param,120)

# %% [markdown]
# Il est tout à fait possible de mettre dans val des K-tests déterministes

# %%
def data_for_val():
    return init_non_periodic(param,120)

# %% [markdown]
# ### Test du solveur

# %%
def generate_fine_solutions(for_train):
    if for_train:
        w_init=data_for_train()
    else:
        w_init=data_for_val()

    
    return core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val=generate_fine_solutions(True)
W_val.shape
# Out:
# traçage de la fonction 'compute_solutions_order1' avec les arguments primitif:
# 		 nb_t,dt_over_dx,dt_over_dx_coarse,nx,nx_coarse,BC_solver,gamma,is_coarse=
# 		 800 0.1 0.009899999999999999 1000 99 reflexive 1.4 False
# 		 et le tenseurs W_init de shape: (120, 1000, 3)
# TensorShape([800, 120, 1000, 3])

# %% [markdown]
# ## Entrainement

# %% [markdown]
# ### Définition des familles d'agent

# %%
fam_size=6
#un durée pour que les agents puissent tous faire leur 'nb_optimization' optimizations
#attention, cela dépend beaucoup de la watch_duration
period_duration="6 steps"#"15 seconds" 
all_agents=[]

# %%
def family_full(window_size,color):
        name="full_"+str(window_size)
        agents=[]
        model_struct = (32,64,32)
        for _ in range(fam_size):
            model=nn.Difference_model_several_convo(param,4)
                 
            agent= aga.Agent_addi(param, 
                            model,
                            watch_duration=20, #20
                            lossCoef_stab=100, #10.
                            lossCoef_ridge=1e-3,
                            lossCoef_disHLL=1,
                            nb_optimization=15,
                            )
            agents.append(agent)
            all_agents.append(agent)
            
        return pop.Family_trainer(
            agents=agents,
            nb_bestweights_averaged=3,
            nb_strong=3,
            nb_weak=2,
            period_duration=period_duration,
            name=name,
            color=color)

family_trainers=[
                 family_full(5,"red"),
                 #family_full(7,"blue"),
                 ]

# %%
def load_data():
    ti=time.time()
    W_train = generate_fine_solutions(True)
    W_val = generate_fine_solutions(False)
    print(f"|génération des données, durée: {time.time()-ti:.2f} ",end="")
    
    ti=time.time()
    for agent in all_agents:
        agent.load_WY_train(W_train)
        agent.load_WY_valid(W_val)
    print(f"|load données,durée: {time.time()-ti:.2f}",end="")

# %% [markdown]
# ### LA BOUCLE

# %%
try:
    for i in range(50):
        load_data()
        for family_trainer in family_trainers:
            family_trainer.period()
except KeyboardInterrupt:
    for family_trainer in family_trainers:
        #pour pouvoir reprendre si on veut
        family_trainer.interupt_period()
# Out:
# |génération des données, durée: 3.60 traçage de la méthode _load_WY_accelerated2 pour les paramètres: W:(800, 120, 1000, 3), nx_ratio:10
# |load données,durée: 0.42
# full_5,échauffement Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# a↗1.0032Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# b↗1.0228Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:5 out of the last 5 calls to <function Agent_addi._predict_accelerated at 0x7f243e8b47a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:6 out of the last 6 calls to <function Agent_addi._predict_accelerated at 0x7f243e8b47a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# c↗1.0103Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:7 out of the last 7 calls to <function Agent_addi._predict_accelerated at 0x7f243db063b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:8 out of the last 8 calls to <function Agent_addi._predict_accelerated at 0x7f243db063b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# d↗1.0128Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:9 out of the last 9 calls to <function Agent_addi._predict_accelerated at 0x7f243cc79b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:10 out of the last 10 calls to <function Agent_addi._predict_accelerated at 0x7f243cc79b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# e↗1.0051Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# Traçage de la méthode gradient_tape avec les tenseurs w_init:(256, 99, 3), w_final:(256, 99, 3)
# 		et les primitifs BC_solver, gamma, dt_over_dx_coarse
# 		 reflexive 1.4 0.009899999999999999
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7f243be95e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True reflexive 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (120, 99, 3)
# WARNING:tensorflow:11 out of the last 11 calls to <function Agent_addi._predict_accelerated at 0x7f243be95e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# f↗0.9911|génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:1 a↗1.0183b↗1.1294c↗1.1003d↗1.1128e↗1.1f↗1.0572
# /!\ L'agent:a est décadent pour la 0-ième fois consécutive; record:1.0183431307474773, scores courants:deque([1.0031720002492268, 1.0183431307474773], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b|f⇇c|a⇇b↫a||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:2 a↗1.2766b↗1.4602-d↗1.3833e↗1.19f↗1.247
# /!\ L'agent:c est décadent pour la 0-ième fois consécutive; record:1.1002529462178547, scores courants:deque([1.0102807680765789, 1.1002529462178547, 1.0150098005930583], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:c⇇b|e⇇d|c⇇b↫c||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:3 --c↗1.4231d↗1.3948--, mutations:f⇇c⇇c|a⇇b↫a⇇b||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:4 a↗1.5451b↗2.1899c↗2.0006d↗2.038e↗1.8635f↗1.9773
# /!\ L'agent:a est décadent pour la 1-ième fois consécutive; record:1.5451332728068035, scores courants:deque([1.4601715405782063, 1.5451332728068035], maxlen=3), best_famparams: {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0007, 'lossCoef_disHLL': 0.7, 'watch_duration': 18}
# , mutations:e⇇d⇇d|a⇇b↫a⇇b⇇c|a⇇b↫a⇇b⇇c↫a||génération des données, durée: 3.52 |load données,durée: 0.01
# full_5,period:5 ------
# /!\ L'agent:a est décadent pour la 2-ième fois consécutive; record:1.5451332728068035, scores courants:deque([1.5451332728068035, 1.071380615234375], maxlen=3), best_famparams: {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0007, 'lossCoef_disHLL': 0.7, 'watch_duration': 18}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b|f⇇c⇇c⇇c|a⇇b↫a⇇b⇇c↫a⇇b⇇d||génération des données, durée: 3.52 |load données,durée: 0.01
# full_5,period:6 ------
# /!\ L'agent:d est décadent pour la 0-ième fois consécutive; record:2.037982940673828, scores courants:deque([2.037982940673828, 1.1423524220784504, 1.2371463775634766], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:d⇇c|e⇇d⇇d⇇f|d⇇c↫d||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:7 a↗2.0446---e↗1.8816-
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([1.1534314155578613, 1.2337456544240315, 1.7585444450378418], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:b⇇a|c⇇b↫c⇇a|b⇇a↫b||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:8 ----e↗2.2339-
# /!\ L'agent:f est décadent pour la 0-ième fois consécutive; record:1.9772758483886719, scores courants:deque([1.3615816434224446, 1.4436095555623372, 1.6762925783793132], maxlen=3), best_famparams: {'lossCoef_stab': 225.0, 'lossCoef_ridge': 0.00105, 'lossCoef_disHLL': 0.48999999999999994, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b|f⇇c⇇c⇇c⇇b|f⇇c⇇c⇇c⇇b↫f||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:9 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, 1.643142859141032, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e|b⇇a↫b⇇a|b⇇a↫b⇇a↫b||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:10 ------
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d|b⇇a↫b⇇a↫b⇇e|b⇇a↫b⇇a↫b⇇e⇇a||génération des données, durée: 3.53 |load données,durée: 0.01
# full_5,period:11 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.044567426045736, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:12 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:13 ------
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a||génération des données, durée: 3.51 |load données,durée: 0.01
# full_5,period:14 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.044567426045736, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b||génération des données, durée: 3.52 |load données,durée: 0.01
# full_5,period:15 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b||génération des données, durée: 3.51 |load données,durée: 0.01
# full_5,period:16 ------
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:17 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.037982940673828, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:18 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:19 ------
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:20 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.233884811401367, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:21 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:22 ------
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:23 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.233884811401367, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e⇇e⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:24 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e⇇e⇇d⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b||génération des données, durée: 3.54 |load données,durée: 0.01
# full_5,period:25 ------
# /!\ L'agent:b est décadent pour la 2-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e⇇e⇇d⇇e⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b⇇e|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b⇇e⇇d||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:26 ------
# /!\ L'agent:b est décadent pour la 0-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.037982940673828, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e⇇e⇇d⇇e⇇a⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b⇇e⇇d⇇a|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b⇇e⇇d⇇a↫b||génération des données, durée: 3.55 |load données,durée: 0.01
# full_5,period:27 ------
# /!\ L'agent:b est décadent pour la 1-ième fois consécutive; record:2.189887364705404, scores courants:deque([2.189887364705404, -inf], maxlen=3), best_famparams: {'lossCoef_stab': 100.0, 'lossCoef_ridge': 0.001, 'lossCoef_disHLL': 1.0, 'watch_duration': 20}
# , mutations:a⇇b↫a⇇b⇇c↫a⇇b⇇d⇇b⇇e⇇d⇇e⇇e⇇e⇇a⇇a⇇a⇇a⇇d⇇a⇇e⇇e⇇e⇇d⇇e⇇a⇇d⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b⇇e⇇d⇇a↫b⇇d|b⇇a↫b⇇a↫b⇇e⇇a⇇e↫b⇇a↫b⇇d⇇a⇇e↫b⇇a↫b⇇d⇇d⇇e↫b⇇e↫b⇇e⇇e⇇a↫b⇇e↫b⇇e⇇e⇇d↫b⇇a↫b⇇e⇇d⇇a↫b⇇d↫b||génération des données, durée: 3.53 |load données,durée: 0.01
# full_5,period:28 --

# %% [markdown]
# ### Historique des `famparams`

# %%
def plot_history_famparams():
    # keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","lossCoef_Laplacian","watch_duration","score"]
    keys=["lossCoef_stab","lossCoef_ridge","lossCoef_disHLL","watch_duration","score"]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_famparams()

# %% [markdown]
# ### Historique des `loss`

# %%
def plot_history_losses():
    # keys=["loss_stab","loss_disHLL","loss_ridge","loss_Laplacian"]
    keys=["loss_stab","loss_disHLL","loss_ridge",
          "loss_stab*coef","loss_disHLL*coef","loss_ridge*coef",
          "score_l1","score_l2","score_linfty"
          ]

    for k in keys:
        fig,ax=plt.subplots()
        for family_trainer in family_trainers:
            family_trainer.plot_metric(k,ax)

    plt.show()
plot_history_losses()

# %% [markdown]
# ## Choix d'une des familles

# %%
family_trainer=family_trainers[0]

# %% [markdown]
# ### Valeurs des famparams

# %%
for name,agent_w in family_trainer.agents.items():
    print(name)
    print(agent_w.agent.famparams)
    print(agent_w.agent.agent_score())


best_agent=family_trainer.get_best_agent()
# best_agent=family_trainer.agents['a'].agent
print("best agent")
print(best_agent.famparams)
# print(best_agent.agent_score())
# Out:
# a
# {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0015, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
# nan
# b
# {'lossCoef_stab': 70.0, 'lossCoef_ridge': 0.0015, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
# nan
# c
# {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.0022500000000000003, 'lossCoef_disHLL': 2.25, 'watch_duration': 20}
# nan
# d
# {'lossCoef_stab': 105.0, 'lossCoef_ridge': 0.0022500000000000003, 'lossCoef_disHLL': 1.0499999999999998, 'watch_duration': 16}
# nan
# e
# {'lossCoef_stab': 157.5, 'lossCoef_ridge': 0.001575, 'lossCoef_disHLL': 0.7349999999999999, 'watch_duration': 18}
# nan
# f
# {'lossCoef_stab': 150.0, 'lossCoef_ridge': 0.0015, 'lossCoef_disHLL': 1.5, 'watch_duration': 18}
# nan
# best agent
# {'lossCoef_stab': 157.5, 'lossCoef_ridge': 0.001575, 'lossCoef_disHLL': 0.7349999999999999, 'watch_duration': 18}

# %% [markdown]
# ## Testons le long du temps

# %%
def compare_along_the_time(W_val):
    nb_t = len(W_val)
    
    best_agent.load_WY_valid(W_val)
    res_fine_proj,res_HLL,res_model=best_agent.predict()
        
    nb_batch_plot=5
    if nb_batch_plot>W_val.shape[1]:
        nb_batch_plot=W_val.shape[1]
    
    nb_t_plot=3
    #pour avoir le permier temps et le dernier
    t_to_plot=np.floor(np.linspace(0,nb_t-1,nb_t_plot)).astype(int)
    if nb_batch_plot==1:ax=ax[:,tf.newaxis]
    
    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    for i,t in enumerate(t_to_plot):
        for j in range(nb_batch_plot):
            ax[i,j].plot(res_fine_proj[t,j,:,0],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,0],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,0],color="r",label="model")
    ax[0,0].legend()    
    ax[0,0].set_title("Rho")
    fig.tight_layout()


    fig, ax = plt.subplots(nb_t_plot,nb_batch_plot,figsize=(15,nb_t_plot*2))
    for i,t in enumerate(t_to_plot):
        for j in range(nb_batch_plot):
            ax[i,j].plot(res_fine_proj[t,j,:,2],color="k",label="fine")
            ax[i,j].plot(res_HLL[t,j,:,2],color="b",label="HLL")
            ax[i,j].plot(res_model[t,j,:,2],color="r",label="model")
    ax[0,0].legend()    
    ax[0,0].set_title("Energie")
    fig.tight_layout()


    errors_HLL=tf.reduce_mean(tf.abs(res_fine_proj-res_HLL),axis=[1,2,3])
    errors_model=tf.reduce_mean(tf.abs(res_fine_proj-res_model),axis=[1,2,3])
    
    fig,ax=plt.subplots()
    ax.plot(errors_HLL,color="b",label="HLL")
    ax.plot(errors_model,color="r",label="model")

    # if (np.max(errors_model)>0.1):
    #     ax.set_ylim(0,0.1)
    
    ax.legend()
    ax.set_xlabel("time")

    plt.show()

# %% [markdown]
# ### kind Periodic

# %%
param.BC_model=param.BC_solver=Param.BC_periodic 
w_init=init_periodic(param,50)
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
print(W_val.shape)
compare_along_the_time(W_val)
# Out:
# (800, 50, 1000, 3)

# %%
param.BC_model=param.BC_solver=Param.BC_reflexive
w_init=init_periodic(param,50)
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
print(W_val.shape)
compare_along_the_time(W_val)
# Out:
# (800, 50, 1000, 3)

# %% [markdown]
# ### kind non-periodic

# %%
param.BC_model=param.BC_solver=Param.BC_reflexive

# %%
w_init=init_non_periodic(param,50)
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# TensorShape([800, 50, 1000, 3])

# %%
compare_along_the_time(W_val)

# %% [markdown]
# ### kind Sod

# %%
def deterministic_SOD(batch_size):
    k=k_tf32
    x = k.arange_float(param.xmin, param.xmax, param.dx)
            
    #La densité peu être assez faible: 0.1 OK, 0.01-> quelques oscilations
    rho_0 =  k.where_float(x < 0.5, 1., 0.5 )+1 #0.125
    #Par contre la pression ne doit pas proche de zéro: avec 0.01 cela craque tout de suite
    P_0 =    k.where_float(x < 0.5, 1., 0.5)+1 #0.1
    P_coefs=np.linspace(1,3,batch_size)

    rho=[rho_0 for _ in range(batch_size)]
    #rho=[rho_0*coef for coef in P_coefs]
    P=np.array([P_0*coef for coef in P_coefs])

    rhoV = k.zeros_float([batch_size, param.nx])
    E=P#/(param.gamma-1)

    return np.stack([rho,rhoV,E],axis=2)

# %%
#w_init=random_SOD(5)
w_init=deterministic_SOD(5)

param.BC_model=param.BC_solver=param.BC_neumann
W_val = core.compute_solutions(param, nb_t, w_init,False, k_tf32)
W_val.shape
# Out:
# traçage de la fonction 'compute_solutions_order1' avec les arguments primitif:
# 		 nb_t,dt_over_dx,dt_over_dx_coarse,nx,nx_coarse,BC_solver,gamma,is_coarse=
# 		 800 0.1 0.009899999999999999 1000 99 neumann 1.4 False
# 		 et le tenseurs W_init de shape: (5, 1000, 3)
# TensorShape([800, 5, 1000, 3])

# %%
compare_along_the_time(W_val)
# Out:
# traçage de la méthode _load_WY_accelerated2 pour les paramètres: W:(800, 5, 1000, 3), nx_ratio:10
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 True neumann 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (5, 99, 3)
# WARNING:tensorflow:6 out of the last 346 calls to <function Agent_addi._predict_accelerated at 0x7f243cc79b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# traçage de la méthode _predict_accelerated avec les arguments primitifs
# 		is_model,  BC_solver, gamma, dt_over_dx_coarse
# 		 False neumann 1.4 0.009899999999999999
# 		et le tenseur w_init de shape (5, 99, 3)
# WARNING:tensorflow:7 out of the last 347 calls to <function Agent_addi._predict_accelerated at 0x7f243cc79b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
